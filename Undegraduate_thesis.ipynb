# %% [markdown]
# Установка необходимых библиотек

# %%
import sberpm

print("Версия SberPM ", sberpm.__version__)
# Out:
# Версия SberPM  3.4.0

# %%
import graphviz

# %% [markdown]
# Предобработка данных

# %%
import pandas as pd

df = pd.read_csv("HR_log_obezlich.csv", sep=";", encoding="utf-8")

print(df.columns)
# Out:
# Index(['case_id', 'line_id', 'from', 'to', 'time'], dtype='object')

# %%
df.head()
# Out:
#    case_id  line_id                     from                       to  \
# 0        1        1                    Новый  Рассмотрение заказчиком
# 1        1        2  Рассмотрение заказчиком         Оценка кандидата
# 2        1        3         Оценка кандидата                 Отклонен
# 3        2        1                    Новый  Рассмотрение заказчиком
# 4        2        2  Рассмотрение заказчиком                 Интервью
#
#          time
# 0  184.081136
# 1  216.771912
# 2  222.700654
# 3  528.787113
# 4  104.049962

# %%
from datetime import datetime, timedelta
import numpy as np

start_datetime = datetime(2024, 1, 1, 0, 0, 0)

df['start_time'] = None
df['end_time'] = None

for case in df['case_id'].unique():
    case_mask = df['case_id'] == case
    case_df = df[case_mask].sort_values(by='line_id')

    start_time = start_datetime
    start_times = []
    end_times = []

    for time in case_df['time']:
        start_times.append(start_time.strftime("%Y-%m-%d %H:%M:%S"))
        end_time = start_time + timedelta(hours=time)
        end_times.append(end_time.strftime("%Y-%m-%d %H:%M:%S"))
        start_time = end_time

    df.loc[case_mask, 'start_time'] = start_times
    df.loc[case_mask, 'end_time'] = end_times

case_offsets = {case: timedelta(hours=np.random.uniform(0.01, 0.1)) for case in df['case_id'].unique()}

df['start_time'] = pd.to_datetime(df['start_time']) + df['case_id'].map(case_offsets)
df['end_time'] = pd.to_datetime(df['end_time']) + df['case_id'].map(case_offsets)

df['start_time'] = df['start_time'].dt.strftime("%Y-%m-%d %H:%M:%S")
df['end_time'] = df['end_time'].dt.strftime("%Y-%m-%d %H:%M:%S")

# %%
df.head()
# Out:
#    case_id  line_id                     from                       to  \
# 0        1        1                    Новый  Рассмотрение заказчиком
# 1        1        2  Рассмотрение заказчиком         Оценка кандидата
# 2        1        3         Оценка кандидата                 Отклонен
# 3        2        1                    Новый  Рассмотрение заказчиком
# 4        2        2  Рассмотрение заказчиком                 Интервью
#
#          time          start_time            end_time  duration_hours
# 0  184.081131 2024-01-01 00:01:56 2024-01-08 16:06:48          662692
# 1  216.771912 2024-01-08 16:06:48 2024-01-17 16:53:06          780378
# 2  222.700653 2024-01-17 16:53:06 2024-01-26 23:35:09          801723
# 3  528.787109 2024-01-01 00:04:53 2024-01-23 00:52:06         1903633
# 4  104.049965 2024-01-23 00:52:06 2024-01-27 08:55:06          374580

# %% [markdown]
# Process Mining исследование с использованием библиотеки sberpm

# %%
from sberpm import DataHolder, DurationUnits, SuccessInputs

data_holder = DataHolder(
    data=df, 
    col_case="case_id", 
    col_stage="to",
    col_start_time="start_time",
    col_end_time="end_time",
    col_duration="time", 
    time_format="%Y-%m-%d %H:%M:%S", 
)
# Out:
# ℹ️ INFO     | sberpm.baza._sota_utils:	Чтение данных...
#
# ℹ️ INFO     | sberpm.baza.holder:	Обработка данных ивент лога...
#
# ℹ️ INFO     | sberpm.baza._data_processing:	Определяем пропуски в текстовых данных...
#
# ℹ️ INFO     | sberpm.baza._data_processing:	Данные будут отсортированы по следующим колонкам: ['case_id', 'start_time', 'end_time', 'to']
#
# ℹ️ INFO     | sberpm.baza._data_processing:	Производится оптимизация типов данных...
#
# ℹ️ INFO     | sberpm.baza.holder:	Обработка данных завершена

# %%
data_holder.data.head()
# Out:
#    case_id  line_id                     from                       to  \
# 0        1        1                    Новый  Рассмотрение заказчиком
# 1        1        2  Рассмотрение заказчиком         Оценка кандидата
# 2        1        3         Оценка кандидата                 Отклонен
# 3        2        1                    Новый  Рассмотрение заказчиком
# 4        2        2  Рассмотрение заказчиком                 Интервью
#
#          time          start_time            end_time
# 0  184.081131 2024-01-01 00:01:56 2024-01-08 16:06:48
# 1  216.771912 2024-01-08 16:06:48 2024-01-17 16:53:06
# 2  222.700653 2024-01-17 16:53:06 2024-01-26 23:35:09
# 3  528.787109 2024-01-01 00:04:53 2024-01-23 00:52:06
# 4  104.049965 2024-01-23 00:52:06 2024-01-27 08:55:06

# %%
from sberpm.miners import SimpleMiner
from sberpm.visual import GraphvizPainter

simple_miner = SimpleMiner(data_holder)
simple_miner.apply()
graph = simple_miner.graph

painter = GraphvizPainter()
painter.apply(graph)
painter.show()
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 12.2.1 (20241206.2353)
#  -->
# <!-- Pages: 1 -->
# <svg width="794pt" height="908pt"
#  viewBox="0.00 0.00 794.28 908.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 904)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-904 790.28,-904 790.28,4 -4,4"/>
# <!-- Рассмотрение заказчиком -->
# <g id="node1" class="node">
# <title>Рассмотрение заказчиком</title>
# <polygon fill="lightgrey" stroke="black" points="425.38,-684 258.62,-684 258.62,-648 425.38,-648 425.38,-684"/>
# <text text-anchor="middle" x="342" y="-660.95" font-family="Times,serif" font-size="14.00">Рассмотрение заказчиком</text>
# </g>
# <!-- Оценка кандидата -->
# <g id="node2" class="node">
# <title>Оценка кандидата</title>
# <polygon fill="lightgrey" stroke="black" points="506.25,-612 383.75,-612 383.75,-576 506.25,-576 506.25,-612"/>
# <text text-anchor="middle" x="445" y="-588.95" font-family="Times,serif" font-size="14.00">Оценка кандидата</text>
# </g>
# <!-- Рассмотрение заказчиком&#45;&gt;Оценка кандидата -->
# <g id="edge21" class="edge">
# <title>Рассмотрение заказчиком&#45;&gt;Оценка кандидата</title>
# <path fill="none" stroke="black" d="M367.73,-647.52C380.6,-638.76 396.38,-628.04 410.31,-618.58"/>
# <polygon fill="black" stroke="black" points="412.05,-621.63 418.35,-613.11 408.11,-615.84 412.05,-621.63"/>
# </g>
# <!-- Отклонен -->
# <g id="node3" class="node">
# <title>Отклонен</title>
# <polygon fill="lightgrey" stroke="black" points="589.5,-468 516.5,-468 516.5,-432 589.5,-432 589.5,-468"/>
# <text text-anchor="middle" x="553" y="-444.95" font-family="Times,serif" font-size="14.00">Отклонен</text>
# </g>
# <!-- Рассмотрение заказчиком&#45;&gt;Отклонен -->
# <g id="edge22" class="edge">
# <title>Рассмотрение заказчиком&#45;&gt;Отклонен</title>
# <path fill="none" stroke="black" d="M345.17,-647.77C349.38,-628.65 358.3,-597.66 375,-576 410.1,-530.47 466.41,-494.88 506.28,-473.52"/>
# <polygon fill="black" stroke="black" points="507.73,-476.71 514.96,-468.97 504.48,-470.51 507.73,-476.71"/>
# </g>
# <!-- Интервью -->
# <g id="node4" class="node">
# <title>Интервью</title>
# <polygon fill="lightgrey" stroke="black" points="272,-612 196,-612 196,-576 272,-576 272,-612"/>
# <text text-anchor="middle" x="234" y="-588.95" font-family="Times,serif" font-size="14.00">Интервью</text>
# </g>
# <!-- Рассмотрение заказчиком&#45;&gt;Интервью -->
# <g id="edge11" class="edge">
# <title>Рассмотрение заказчиком&#45;&gt;Интервью</title>
# <path fill="none" stroke="black" d="M315.03,-647.52C301.39,-638.68 284.66,-627.84 269.95,-618.3"/>
# <polygon fill="black" stroke="black" points="272.2,-615.59 261.9,-613.08 268.39,-621.46 272.2,-615.59"/>
# </g>
# <!-- Планирование интервью -->
# <g id="node12" class="node">
# <title>Планирование интервью</title>
# <polygon fill="lightgrey" stroke="black" points="328.12,-540 165.88,-540 165.88,-504 328.12,-504 328.12,-540"/>
# <text text-anchor="middle" x="247" y="-516.95" font-family="Times,serif" font-size="14.00">Планирование интервью</text>
# </g>
# <!-- Рассмотрение заказчиком&#45;&gt;Планирование интервью -->
# <g id="edge35" class="edge">
# <title>Рассмотрение заказчиком&#45;&gt;Планирование интервью</title>
# <path fill="none" stroke="black" d="M335.6,-647.7C328.28,-629.07 315.19,-599.02 299,-576 292.1,-566.19 283.35,-556.52 275.01,-548.17"/>
# <polygon fill="black" stroke="black" points="277.59,-545.8 267.97,-541.37 272.73,-550.83 277.59,-545.8"/>
# </g>
# <!-- Оценка кандидата&#45;&gt;Отклонен -->
# <g id="edge31" class="edge">
# <title>Оценка кандидата&#45;&gt;Отклонен</title>
# <path fill="none" stroke="black" d="M458.24,-575.59C476.97,-550.97 511.32,-505.8 533.12,-477.14"/>
# <polygon fill="black" stroke="black" points="535.8,-479.39 539.07,-469.32 530.23,-475.16 535.8,-479.39"/>
# </g>
# <!-- endevent -->
# <g id="node19" class="node">
# <title>endevent</title>
# <ellipse fill="red" stroke="black" cx="586" cy="-18" rx="18" ry="18"/>
# </g>
# <!-- Отклонен&#45;&gt;endevent -->
# <g id="edge3" class="edge">
# <title>Отклонен&#45;&gt;endevent</title>
# <path fill="none" stroke="black" d="M553,-431.51C553,-404.71 553,-351.87 553,-307 553,-307 553,-307 553,-161 553,-120.07 566.17,-74.18 575.87,-45.94"/>
# <polygon fill="black" stroke="black" points="579.08,-47.35 579.13,-36.75 572.49,-45.01 579.08,-47.35"/>
# </g>
# <!-- Интервью&#45;&gt;Интервью -->
# <g id="edge41" class="edge">
# <title>Интервью&#45;&gt;Интервью</title>
# <path fill="none" stroke="black" d="M272.48,-607.36C282.47,-606.54 290,-602.09 290,-594 290,-589.33 287.48,-585.86 283.43,-583.62"/>
# <polygon fill="black" stroke="black" points="284.5,-580.28 273.94,-581.04 282.67,-587.04 284.5,-580.28"/>
# </g>
# <!-- Заполнение анкеты -->
# <g id="node5" class="node">
# <title>Заполнение анкеты</title>
# <polygon fill="lightgrey" stroke="black" points="130,-540 0,-540 0,-504 130,-504 130,-540"/>
# <text text-anchor="middle" x="65" y="-516.95" font-family="Times,serif" font-size="14.00">Заполнение анкеты</text>
# </g>
# <!-- Интервью&#45;&gt;Заполнение анкеты -->
# <g id="edge37" class="edge">
# <title>Интервью&#45;&gt;Заполнение анкеты</title>
# <path fill="none" stroke="black" d="M195.65,-577.12C172.56,-567.55 142.83,-555.24 117.57,-544.77"/>
# <polygon fill="black" stroke="black" points="119.03,-541.59 108.45,-541 116.35,-548.06 119.03,-541.59"/>
# </g>
# <!-- Интервью&#45;&gt;Планирование интервью -->
# <g id="edge19" class="edge">
# <title>Интервью&#45;&gt;Планирование интервью</title>
# <path fill="none" stroke="black" d="M231.3,-575.7C231.91,-568.32 233.3,-559.52 235.12,-551.25"/>
# <polygon fill="black" stroke="black" points="238.51,-552.12 237.56,-541.57 231.72,-550.41 238.51,-552.12"/>
# </g>
# <!-- Заполнение анкеты&#45;&gt;Заполнение анкеты -->
# <g id="edge42" class="edge">
# <title>Заполнение анкеты&#45;&gt;Заполнение анкеты</title>
# <path fill="none" stroke="black" d="M130.41,-534.43C140.85,-532.61 148,-528.47 148,-522 148,-518.16 145.48,-515.14 141.25,-512.94"/>
# <polygon fill="black" stroke="black" points="142.45,-509.64 131.86,-510.02 140.37,-516.33 142.45,-509.64"/>
# </g>
# <!-- Проверка -->
# <g id="node6" class="node">
# <title>Проверка</title>
# <polygon fill="lightgrey" stroke="black" points="162.75,-468 91.25,-468 91.25,-432 162.75,-432 162.75,-468"/>
# <text text-anchor="middle" x="127" y="-444.95" font-family="Times,serif" font-size="14.00">Проверка</text>
# </g>
# <!-- Заполнение анкеты&#45;&gt;Проверка -->
# <g id="edge8" class="edge">
# <title>Заполнение анкеты&#45;&gt;Проверка</title>
# <path fill="none" stroke="black" d="M80.33,-503.7C87.53,-495.56 96.28,-485.69 104.24,-476.7"/>
# <polygon fill="black" stroke="black" points="106.84,-479.04 110.85,-469.24 101.6,-474.4 106.84,-479.04"/>
# </g>
# <!-- Решение о найме -->
# <g id="node7" class="node">
# <title>Решение о найме</title>
# <polygon fill="lightgrey" stroke="black" points="353.62,-396 236.38,-396 236.38,-360 353.62,-360 353.62,-396"/>
# <text text-anchor="middle" x="295" y="-372.95" font-family="Times,serif" font-size="14.00">Решение о найме</text>
# </g>
# <!-- Проверка&#45;&gt;Решение о найме -->
# <g id="edge25" class="edge">
# <title>Проверка&#45;&gt;Решение о найме</title>
# <path fill="none" stroke="black" d="M163.04,-433.98C186.26,-424.31 216.83,-411.57 242.7,-400.79"/>
# <polygon fill="black" stroke="black" points="243.81,-404.12 251.7,-397.04 241.12,-397.66 243.81,-404.12"/>
# </g>
# <!-- Согласование офера в компании -->
# <g id="node8" class="node">
# <title>Согласование офера в компании</title>
# <polygon fill="lightgrey" stroke="black" points="482.62,-324 275.38,-324 275.38,-288 482.62,-288 482.62,-324"/>
# <text text-anchor="middle" x="379" y="-300.95" font-family="Times,serif" font-size="14.00">Согласование офера в компании</text>
# </g>
# <!-- Решение о найме&#45;&gt;Согласование офера в компании -->
# <g id="edge36" class="edge">
# <title>Решение о найме&#45;&gt;Согласование офера в компании</title>
# <path fill="none" stroke="black" d="M315.76,-359.7C325

# %%
from sberpm.miners import AlphaMiner

alpha_miner = AlphaMiner(data_holder)
alpha_miner.apply()
graph = alpha_miner.graph

painter = GraphvizPainter()
painter.apply(graph)
painter.show()
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 12.2.1 (20241206.2353)
#  -->
# <!-- Pages: 1 -->
# <svg width="1099pt" height="836pt"
#  viewBox="0.00 0.00 1099.00 836.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 832)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-832 1095,-832 1095,4 -4,4"/>
# <!-- Рассмотрение заказчиком -->
# <g id="node1" class="node">
# <title>Рассмотрение заказчиком</title>
# <polygon fill="lightgrey" stroke="black" points="725.38,-396 558.62,-396 558.62,-360 725.38,-360 725.38,-396"/>
# <text text-anchor="middle" x="642" y="-372.95" font-family="Times,serif" font-size="14.00">Рассмотрение заказчиком</text>
# </g>
# <!-- Рассмотрение заказчиком &#45;&gt; Планирование интервью,Оценка кандидата -->
# <g id="node26" class="node">
# <title>Рассмотрение заказчиком &#45;&gt; Планирование интервью,Оценка кандидата</title>
# <ellipse fill="none" stroke="black" cx="268" cy="-306" rx="27" ry="18"/>
# </g>
# <!-- Рассмотрение заказчиком&#45;&gt;Рассмотрение заказчиком &#45;&gt; Планирование интервью,Оценка кандидата -->
# <g id="edge17" class="edge">
# <title>Рассмотрение заказчиком&#45;&gt;Рассмотрение заказчиком &#45;&gt; Планирование интервью,Оценка кандидата</title>
# <path fill="none" stroke="black" d="M558.2,-370.56C488.88,-363.66 388.45,-349.97 304,-324 302.39,-323.5 300.76,-322.95 299.13,-322.35"/>
# <polygon fill="black" stroke="black" points="300.51,-319.13 289.93,-318.51 297.81,-325.59 300.51,-319.13"/>
# </g>
# <!-- Рассмотрение заказчиком,Самоотказ,Оформление,Готов к переводу &#45;&gt; Отклонен,Оформлен -->
# <g id="node31" class="node">
# <title>Рассмотрение заказчиком,Самоотказ,Оформление,Готов к переводу &#45;&gt; Отклонен,Оформлен</title>
# <ellipse fill="none" stroke="black" cx="634" cy="-162" rx="27" ry="18"/>
# </g>
# <!-- Рассмотрение заказчиком&#45;&gt;Рассмотрение заказчиком,Самоотказ,Оформление,Готов к переводу &#45;&gt; Отклонен,Оформлен -->
# <g id="edge37" class="edge">
# <title>Рассмотрение заказчиком&#45;&gt;Рассмотрение заказчиком,Самоотказ,Оформление,Готов к переводу &#45;&gt; Отклонен,Оформлен</title>
# <path fill="none" stroke="black" d="M645.29,-359.96C650.47,-330.45 659.14,-268 651,-216 649.68,-207.56 647.25,-198.64 644.62,-190.56"/>
# <polygon fill="black" stroke="black" points="647.99,-189.58 641.39,-181.29 641.38,-191.88 647.99,-189.58"/>
# </g>
# <!-- Рассмотрение заказчиком,Оформление,Готов к переводу,Резерв &#45;&gt; Отклонен,Оформлен -->
# <g id="node32" class="node">
# <title>Рассмотрение заказчиком,Оформление,Готов к переводу,Резерв &#45;&gt; Отклонен,Оформлен</title>
# <ellipse fill="none" stroke="black" cx="754" cy="-162" rx="27" ry="18"/>
# </g>
# <!-- Рассмотрение заказчиком&#45;&gt;Рассмотрение заказчиком,Оформление,Готов к переводу,Резерв &#45;&gt; Отклонен,Оформлен -->
# <g id="edge43" class="edge">
# <title>Рассмотрение заказчиком&#45;&gt;Рассмотрение заказчиком,Оформление,Готов к переводу,Резерв &#45;&gt; Отклонен,Оформлен</title>
# <path fill="none" stroke="black" d="M700.44,-359.67C748.63,-341.69 812.85,-308.15 837,-252 843.32,-237.3 844.69,-230.03 837,-216 826.61,-197.04 806.23,-183.88 788.26,-175.41"/>
# <polygon fill="black" stroke="black" points="789.74,-172.23 779.17,-171.45 786.94,-178.65 789.74,-172.23"/>
# </g>
# <!-- Оценка кандидата -->
# <g id="node2" class="node">
# <title>Оценка кандидата</title>
# <polygon fill="lightgrey" stroke="black" points="232.25,-252 109.75,-252 109.75,-216 232.25,-216 232.25,-252"/>
# <text text-anchor="middle" x="171" y="-228.95" font-family="Times,serif" font-size="14.00">Оценка кандидата</text>
# </g>
# <!-- Не выходит на связь,Планирование интервью,Оценка кандидата &#45;&gt; Отклонен -->
# <g id="node28" class="node">
# <title>Не выходит на связь,Планирование интервью,Оценка кандидата &#45;&gt; Отклонен</title>
# <ellipse fill="none" stroke="black" cx="251" cy="-162" rx="27" ry="18"/>
# </g>
# <!-- Оценка кандидата&#45;&gt;Не выходит на связь,Планирование интервью,Оценка кандидата &#45;&gt; Отклонен -->
# <g id="edge26" class="edge">
# <title>Оценка кандидата&#45;&gt;Не выходит на связь,Планирование интервью,Оценка кандидата &#45;&gt; Отклонен</title>
# <path fill="none" stroke="black" d="M190.78,-215.7C201.69,-206.15 215.33,-194.21 226.87,-184.12"/>
# <polygon fill="black" stroke="black" points="228.84,-187.04 234.06,-177.82 224.23,-181.77 228.84,-187.04"/>
# </g>
# <!-- Готов к переводу,Оценка кандидата,Оформление,Резерв,Планирование интервью &#45;&gt; Отклонен,Оформлен -->
# <g id="node33" class="node">
# <title>Готов к переводу,Оценка кандидата,Оформление,Резерв,Планирование интервью &#45;&gt; Отклонен,Оформлен</title>
# <ellipse fill="none" stroke="black" cx="562" cy="-162" rx="27" ry="18"/>
# </g>
# <!-- Оценка кандидата&#45;&gt;Готов к переводу,Оценка кандидата,Оформление,Резерв,Планирование интервью &#45;&gt; Отклонен,Оформлен -->
# <g id="edge50" class="edge">
# <title>Оценка кандидата&#45;&gt;Готов к переводу,Оценка кандидата,Оформление,Резерв,Планирование интервью &#45;&gt; Отклонен,Оформлен</title>
# <path fill="none" stroke="black" d="M232.38,-217.68C235.29,-217.08 238.17,-216.52 241,-216 366.57,-192.9 403.42,-215.7 526,-180 527.62,-179.53 529.25,-178.99 530.89,-178.41"/>
# <polygon fill="black" stroke="black" points="532.18,-181.66 540.1,-174.62 529.52,-175.19 532.18,-181.66"/>
# </g>
# <!-- Готов к переводу,Оценка кандидата,Оформление,Самоотказ,Планирование интервью &#45;&gt; Отклонен,Оформлен -->
# <g id="node34" class="node">
# <title>Готов к переводу,Оценка кандидата,Оформление,Самоотказ,Планирование интервью &#45;&gt; Отклонен,Оформлен</title>
# <ellipse fill="none" stroke="black" cx="490" cy="-162" rx="27" ry="18"/>
# </g>
# <!-- Оценка кандидата&#45;&gt;Готов к переводу,Оценка кандидата,Оформление,Самоотказ,Планирование интервью &#45;&gt; Отклонен,Оформлен -->
# <g id="edge57" class="edge">
# <title>Оценка кандидата&#45;&gt;Готов к переводу,Оценка кандидата,Оформление,Самоотказ,Планирование интервью &#45;&gt; Отклонен,Оформлен</title>
# <path fill="none" stroke="black" d="M232.44,-217.97C235.33,-217.3 238.2,-216.64 241,-216 316.04,-198.9 404.21,-180.54 452.92,-170.55"/>
# <polygon fill="black" stroke="black" points="453.56,-173.99 462.65,-168.56 452.16,-167.13 453.56,-173.99"/>
# </g>
# <!-- Отклонен -->
# <g id="node3" class="node">
# <title>Отклонен</title>
# <polygon fill="lightgrey" stroke="black" points="551.5,-108 478.5,-108 478.5,-72 551.5,-72 551.5,-108"/>
# <text text-anchor="middle" x="515" y="-84.95" font-family="Times,serif" font-size="14.00">Отклонен</text>
# </g>
# <!-- endevent -->
# <g id="node19" class="node">
# <title>endevent</title>
# <ellipse fill="red" stroke="black" cx="561" cy="-18" rx="18" ry="18"/>
# </g>
# <!-- Отклонен&#45;&gt;endevent -->
# <g id="edge3" class="edge">
# <title>Отклонен&#45;&gt;endevent</title>
# <path fill="none" stroke="black" d="M526.37,-71.7C532,-63.13 538.89,-52.65 545.03,-43.3"/>
# <polygon fill="black" stroke="black" points="547.92,-45.28 550.48,-35 542.07,-41.44 547.92,-45.28"/>
# </g>
# <!-- Интервью -->
# <g id="node4" class="node">
# <title>Интервью</title>
# <polygon fill="lightgrey" stroke="black" points="943,-828 867,-828 867,-792 943,-792 943,-828"/>
# <text text-anchor="middle" x="905" y="-804.95" font-family="Times,serif" font-size="14.00">Интервью</text>
# </g>
# <!-- Заполнение анкеты -->
# <g id="node5" class="node">
# <title>Заполнение анкеты</title>
# <polygon fill="lightgrey" stroke="black" points="1091,-828 961,-828 961,-792 1091,-792 1091,-828"/>
# <text text-anchor="middle" x="1026" y="-804.95" font-family="Times,serif" font-size="14.00">Заполнение анкеты</text>
# </g>
# <!-- Проверка -->
# <g id="node6" class="node">
# <title>Проверка</title>
# <polygon fill="lightgrey" stroke="black" points="848.75,-828 777.25,-828 777.25,-792 848.75,-792 848.75,-828"/>
# <text text-anchor="middle" x="813" y="-804.95" font-family="Times,serif" font-size="14.00">Проверка</text>
# </g>
# <!-- Проверка &#45;&gt; Решение о найме -->
# <g id="nod

# %%
from sberpm.miners import AlphaPlusMiner

alpha_plus_miner = AlphaPlusMiner(data_holder)
alpha_plus_miner.apply()
graph = alpha_plus_miner.graph

painter = GraphvizPainter()
painter.apply(graph)
painter.show()
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 12.2.1 (20241206.2353)
#  -->
# <!-- Pages: 1 -->
# <svg width="818pt" height="1196pt"
#  viewBox="0.00 0.00 818.12 1196.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 1192)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-1192 814.12,-1192 814.12,4 -4,4"/>
# <!-- Рассмотрение заказчиком -->
# <g id="node1" class="node">
# <title>Рассмотрение заказчиком</title>
# <polygon fill="lightgrey" stroke="black" points="350.38,-972 183.62,-972 183.62,-936 350.38,-936 350.38,-972"/>
# <text text-anchor="middle" x="267" y="-948.95" font-family="Times,serif" font-size="14.00">Рассмотрение заказчиком</text>
# </g>
# <!-- Рассмотрение заказчиком &#45;&gt; Проверка,Оценка кандидата -->
# <g id="node26" class="node">
# <title>Рассмотрение заказчиком &#45;&gt; Проверка,Оценка кандидата</title>
# <ellipse fill="none" stroke="black" cx="520" cy="-882" rx="27" ry="18"/>
# </g>
# <!-- Рассмотрение заказчиком&#45;&gt;Рассмотрение заказчиком &#45;&gt; Проверка,Оценка кандидата -->
# <g id="edge17" class="edge">
# <title>Рассмотрение заказчиком&#45;&gt;Рассмотрение заказчиком &#45;&gt; Проверка,Оценка кандидата</title>
# <path fill="none" stroke="black" d="M330.19,-935.52C378.81,-922.06 444.25,-903.96 484.21,-892.9"/>
# <polygon fill="black" stroke="black" points="485.09,-896.29 493.8,-890.25 483.23,-889.54 485.09,-896.29"/>
# </g>
# <!-- Рассмотрение заказчиком,Оформление,Готов к переводу,Резерв &#45;&gt; Отклонен,Оформлен,Проверка -->
# <g id="node33" class="node">
# <title>Рассмотрение заказчиком,Оформление,Готов к переводу,Резерв &#45;&gt; Отклонен,Оформлен,Проверка</title>
# <ellipse fill="none" stroke="black" cx="216" cy="-162" rx="27" ry="18"/>
# </g>
# <!-- Рассмотрение заказчиком&#45;&gt;Рассмотрение заказчиком,Оформление,Готов к переводу,Резерв &#45;&gt; Отклонен,Оформлен,Проверка -->
# <g id="edge47" class="edge">
# <title>Рассмотрение заказчиком&#45;&gt;Рассмотрение заказчиком,Оформление,Готов к переводу,Резерв &#45;&gt; Отклонен,Оформлен,Проверка</title>
# <path fill="none" stroke="black" d="M183.27,-947.22C141.16,-940.78 91.28,-927.45 54,-900 16.74,-872.57 0,-857.27 0,-811 0,-811 0,-811 0,-305 0,-220.47 116.94,-183.46 178.73,-169.8"/>
# <polygon fill="black" stroke="black" points="179.4,-173.23 188.46,-167.75 177.96,-166.38 179.4,-173.23"/>
# </g>
# <!-- Рассмотрение заказчиком,Самоотказ,Оформление,Готов к переводу &#45;&gt; Отклонен,Оформлен,Проверка -->
# <g id="node34" class="node">
# <title>Рассмотрение заказчиком,Самоотказ,Оформление,Готов к переводу &#45;&gt; Отклонен,Оформлен,Проверка</title>
# <ellipse fill="none" stroke="black" cx="288" cy="-162" rx="27" ry="18"/>
# </g>
# <!-- Рассмотрение заказчиком&#45;&gt;Рассмотрение заказчиком,Самоотказ,Оформление,Готов к переводу &#45;&gt; Отклонен,Оформлен,Проверка -->
# <g id="edge54" class="edge">
# <title>Рассмотрение заказчиком&#45;&gt;Рассмотрение заказчиком,Самоотказ,Оформление,Готов к переводу &#45;&gt; Отклонен,Оформлен,Проверка</title>
# <path fill="none" stroke="black" d="M183.35,-936.67C117.94,-918.47 38,-881.75 38,-811 38,-811 38,-811 38,-521 38,-377.92 39.22,-316.56 141,-216 177.89,-179.55 203.79,-199.11 252,-180 253.53,-179.4 255.08,-178.76 256.64,-178.09"/>
# <polygon fill="black" stroke="black" points="257.79,-181.41 265.5,-174.14 254.94,-175.02 257.79,-181.41"/>
# </g>
# <!-- Оценка кандидата -->
# <g id="node2" class="node">
# <title>Оценка кандидата</title>
# <polygon fill="lightgrey" stroke="black" points="684.25,-252 561.75,-252 561.75,-216 684.25,-216 684.25,-252"/>
# <text text-anchor="middle" x="623" y="-228.95" font-family="Times,serif" font-size="14.00">Оценка кандидата</text>
# </g>
# <!-- Не выходит на связь,Оценка кандидата &#45;&gt; Отклонен -->
# <g id="node27" class="node">
# <title>Не выходит на связь,Оценка кандидата &#45;&gt; Отклонен</title>
# <ellipse fill="none" stroke="black" cx="623" cy="-162" rx="27" ry="18"/>
# </g>
# <!-- Оценка кандидата&#45;&gt;Не выходит на связь,Оценка кандидата &#45;&gt; Отклонен -->
# <g id="edge21" class="edge">
# <title>Оценка кандидата&#45;&gt;Не выходит на связь,Оценка кандидата &#45;&gt; Отклонен</title>
# <path fill="none" stroke="black" d="M623,-215.7C623,-208.41 623,-199.73 623,-191.54"/>
# <polygon fill="black" stroke="black" points="626.5,-191.62 623,-181.62 619.5,-191.62 626.5,-191.62"/>
# </g>
# <!-- Резерв,Оформление,Готов к переводу,Оценка кандидата &#45;&gt; Отклонен,Оформлен -->
# <g id="node31" class="node">
# <title>Резерв,Оформление,Готов к переводу,Оценка кандидата &#45;&gt; Отклонен,Оформлен</title>
# <ellipse fill="none" stroke="black" cx="360" cy="-162" rx="27" ry="18"/>
# </g>
# <!-- Оценка кандидата&#45;&gt;Резерв,Оформление,Готов к переводу,Оценка кандидата &#45;&gt; Отклонен,Оформлен -->
# <g id="edge38" class="edge">
# <title>Оценка кандидата&#45;&gt;Резерв,Оформление,Готов к переводу,Оценка кандидата &#45;&gt; Отклонен,Оформлен</title>
# <path fill="none" stroke="black" d="M561.34,-218.43C557.84,-217.6 554.38,-216.79 551,-216 482.14,-199.87 462.8,-203.23 396,-180 394.45,-179.46 392.88,-178.88 391.3,-178.26"/>
# <polygon fill="black" stroke="black" points="392.97,-175.16 382.4,-174.43 390.2,-181.6 392.97,-175.16"/>
# </g>
# <!-- Самоотказ,Оформление,Готов к переводу,Оценка кандидата &#45;&gt; Отклонен,Оформлен -->
# <g id="node32" class="node">
# <title>Самоотказ,Оформление,Готов к переводу,Оценка кандидата &#45;&gt; Отклонен,Оформлен</title>
# <ellipse fill="none" stroke="black" cx="432" cy="-162" rx="27" ry="18"/>
# </g>
# <!-- Оценка кандидата&#45;&gt;Самоотказ,Оформление,Готов к переводу,Оценка кандидата &#45;&gt; Отклонен,Оформлен -->
# <g id="edge44" class="edge">
# <title>Оценка кандидата&#45;&gt;Самоотказ,Оформление,Готов к переводу,Оценка кандидата &#45;&gt; Отклонен,Оформлен</title>
# <path fill="none" stroke="black" d="M575.3,-215.52C541.25,-203.04 496.28,-186.56 465.86,-175.41"/>
# <polygon fill="black" stroke="black" points="467.38,-172.24 456.79,-172.08 464.97,-178.81 467.38,-172.24"/>
# </g>
# <!-- Отклонен -->
# <g id="node3" class="node">
# <title>Отклонен</title>
# <polygon fill="lightgrey" stroke="black" points="442.5,-108 369.5,-108 369.5,-72 442.5,-72 442.5,-108"/>
# <text text-anchor="middle" x="406" y="-84.95" font-family="Times,serif" font-size="14.00">Отклонен</text>
# </g>
# <!-- endevent -->
# <g id="node19" class="node">
# <title>endevent</title>
# <ellipse fill="red" stroke="black" cx="359" cy="-18" rx="18" ry="18"/>
# </g>
# <!-- Отклонен&#45;&gt;endevent -->
# <g id="edge3" class="edge">
# <title>Отклонен&#45;&gt;endevent</title>
# <path fill="none" stroke="black" d="M394.38,-71.7C388.49,-62.92 381.25,-52.13 374.85,-42.61"/>
# <polygon fill="black" stroke="black" points="377.91,-40.89 369.43,-34.54 372.1,-44.79 377.91,-40.89"/>
# </g>
# <!-- Интервью -->
# <g id="node4" class="node">
# <title>Интервью</title>
# <polygon fill="lightgrey" stroke="black" points="558,-828 482,-828 482,-792 558,-792 558,-828"/>
# <text text-anchor="middle" x="520" y="-804.95" font-family="Times,serif" font-size="14.00">Интервью</text>
# </g>
# <!-- Интервью&#45;&gt;Рассмотрение заказчиком &#45;&gt; Проверка,Оценка кандидата -->
# <g id="edge61" class="edge">
# <title>Интервью&#45;&gt;Рассмотрение заказчиком &#45;&gt; Проверка,Оценка кандидата</title>
# <path fill="none" stroke="black" d="M525.91,-828.28C526.67,-835.6 526.91,-844.34 526.64,-852.57"/>
# <polygon fill="black" stroke="black" points="523.15,-852.33 525.98,-862.54 530.14,-852.8 523.15,-852.33"/>
# </g>
# <!-- Заполнение анкеты -->
# <g id="node5" class="node">
# <title>Заполнение анкеты</title>
# <polygon fill="lightgrey" stroke="black" points="630,-1188 500,-1188 500,-1152 630,-1152 630,-1188"/>
# <text text-anchor="middle" x="565" y="-1164.95" font-family="Times,serif" font-size="14.00">Заполнение анкеты</text>
# </g>
# <!-- Проверка -->
# <g id="node6" class="node">
# <title>Проверка</title>
# <polygon fill="lightgrey" stroke="black" points="180.75,-828 109.25,-828 109.25,-792 180.

# %%
from sberpm.metrics import IdMetric

metrics = IdMetric(data_holder)
metrics.apply().head()
# Out:
#                                                trace  trace_length  \
# 1  (Рассмотрение заказчиком, Оценка кандидата, От...             3
# 2  (Рассмотрение заказчиком, Интервью, Заполнение...             9
# 3                (Рассмотрение заказчиком, Отклонен)             2
# 4  (Рассмотрение заказчиком, Планирование интервь...            11
# 5  (Рассмотрение рекрутером, Готов к переводу, Оф...             3
#
#                                    unique_activities  unique_activities_num  \
# 1  {Рассмотрение заказчиком, Отклонен, Оценка кан...                      3
# 2  {Рассмотрение заказчиком, Решение о найме, Инт...                      9
# 3                {Рассмотрение заказчиком, Отклонен}                      2
# 4  {Рассмотрение заказчиком, Решение о найме, Инт...                     10
# 5  {Рассмотрение рекрутером, Оформлен, Готов к пе...                      3
#
#    loop_percent  total_duration  mean_duration  median_duration  max_duration  \
# 1      0.000000        0.173209       0.057736         0.060214      0.061861
# 2      0.000000        0.470658       0.052295         0.028903      0.146885
# 3      0.000000        0.239366       0.119683         0.119683      0.180747
# 4      9.090909        0.402976       0.036634         0.014057      0.190110
# 5      0.000000        0.226572       0.075524         0.040362      0.185223
#
#    min_duration  probability  variance_duration  std_duration
# 1      0.051134        0.001           0.000022      0.004717
# 2      0.000241        0.001           0.002824      0.053138
# 3      0.058619        0.001           0.003729      0.061064
# 4      0.000438        0.001           0.002737      0.052313
# 5      0.000987        0.001           0.006275      0.079217

# %%
from sberpm.metrics import TraceMetric

trace_metric = TraceMetric(data_holder, time_unit='d')
res = trace_metric.apply().sort_values('total_duration', ascending=False)
res.mean_duration.head()
# Out:
# ⚠️ WARNING  | sberpm.metrics._trace_metric:	DataHolder instance has no user column. Skipping 'unique_users' metric calculation
#
# ⚠️ WARNING  | sberpm.metrics._trace_metric:	DataHolder instance has no user column. Skipping 'unique_users_num' metric calculation
# (Рассмотрение заказчиком, Оценка кандидата, Отклонен)         0.013165
# (Рассмотрение заказчиком, Планирование интервью, Отклонен)    0.013054
# (Рассмотрение рекрутером, Резерв, Отклонен)                   0.052327
# (Рассмотрение заказчиком, Отклонен)                           0.008773
# (Рассмотрение рекрутером, Резерв, Самоотказ, Отклонен)        0.060300
# Name: mean_duration, dtype: float64

# %%
from sberpm.metrics import ActivityMetric

activity_metric = ActivityMetric(data_holder)
nodes_count_metric = activity_metric.count().to_dict()
nodes_mean_metric = activity_metric.mean_duration().to_dict()

graph = simple_miner.graph
graph.add_node_metric('count', nodes_count_metric)
graph.add_node_metric('mean_duration', nodes_mean_metric)

painter = GraphvizPainter()
painter.apply(graph)
painter.show()
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 12.2.1 (20241206.2353)
#  -->
# <!-- Pages: 1 -->
# <svg width="872pt" height="1145pt"
#  viewBox="0.00 0.00 872.47 1144.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 1140.5)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-1140.5 868.47,-1140.5 868.47,4 -4,4"/>
# <!-- Рассмотрение заказчиком -->
# <g id="node1" class="node">
# <title>Рассмотрение заказчиком</title>
# <polygon fill="lightgrey" stroke="black" points="445.38,-877.5 278.62,-877.5 278.62,-820 445.38,-820 445.38,-877.5"/>
# <text text-anchor="middle" x="362" y="-860.2" font-family="Times,serif" font-size="14.00">Рассмотрение заказчиком</text>
# <text text-anchor="middle" x="362" y="-843.7" font-family="Times,serif" font-size="14.00">count: 569</text>
# <text text-anchor="middle" x="362" y="-827.2" font-family="Times,serif" font-size="14.00">mean_duration: 0.094</text>
# </g>
# <!-- Оценка кандидата -->
# <g id="node2" class="node">
# <title>Оценка кандидата</title>
# <polygon fill="lightgrey" stroke="black" points="526,-784 390,-784 390,-726.5 526,-726.5 526,-784"/>
# <text text-anchor="middle" x="458" y="-766.7" font-family="Times,serif" font-size="14.00">Оценка кандидата</text>
# <text text-anchor="middle" x="458" y="-750.2" font-family="Times,serif" font-size="14.00">count: 252</text>
# <text text-anchor="middle" x="458" y="-733.7" font-family="Times,serif" font-size="14.00">mean_duration: 0.089</text>
# </g>
# <!-- Рассмотрение заказчиком&#45;&gt;Оценка кандидата -->
# <g id="edge21" class="edge">
# <title>Рассмотрение заказчиком&#45;&gt;Оценка кандидата</title>
# <path fill="none" stroke="black" d="M391.59,-819.55C400.71,-810.86 410.87,-801.17 420.45,-792.04"/>
# <polygon fill="black" stroke="black" points="422.76,-794.68 427.58,-785.24 417.93,-789.61 422.76,-794.68"/>
# </g>
# <!-- Отклонен -->
# <g id="node3" class="node">
# <title>Отклонен</title>
# <polygon fill="lightgrey" stroke="black" points="650,-597 514,-597 514,-539.5 650,-539.5 650,-597"/>
# <text text-anchor="middle" x="582" y="-579.7" font-family="Times,serif" font-size="14.00">Отклонен</text>
# <text text-anchor="middle" x="582" y="-563.2" font-family="Times,serif" font-size="14.00">count: 768</text>
# <text text-anchor="middle" x="582" y="-546.7" font-family="Times,serif" font-size="14.00">mean_duration: 0.114</text>
# </g>
# <!-- Рассмотрение заказчиком&#45;&gt;Отклонен -->
# <g id="edge22" class="edge">
# <title>Рассмотрение заказчиком&#45;&gt;Отклонен</title>
# <path fill="none" stroke="black" d="M360.79,-819.61C360.93,-793.73 364.36,-755.15 381,-726.5 412.4,-672.42 470.27,-630.17 515.89,-603.15"/>
# <polygon fill="black" stroke="black" points="517.51,-606.25 524.4,-598.21 514,-600.2 517.51,-606.25"/>
# </g>
# <!-- Интервью -->
# <g id="node4" class="node">
# <title>Интервью</title>
# <polygon fill="lightgrey" stroke="black" points="278,-784 142,-784 142,-726.5 278,-726.5 278,-784"/>
# <text text-anchor="middle" x="210" y="-766.7" font-family="Times,serif" font-size="14.00">Интервью</text>
# <text text-anchor="middle" x="210" y="-750.2" font-family="Times,serif" font-size="14.00">count: 814</text>
# <text text-anchor="middle" x="210" y="-733.7" font-family="Times,serif" font-size="14.00">mean_duration: 0.049</text>
# </g>
# <!-- Рассмотрение заказчиком&#45;&gt;Интервью -->
# <g id="edge11" class="edge">
# <title>Рассмотрение заказчиком&#45;&gt;Интервью</title>
# <path fill="none" stroke="black" d="M315.15,-819.55C299.77,-810.29 282.5,-799.89 266.48,-790.25"/>
# <polygon fill="black" stroke="black" points="268.36,-787.3 257.99,-785.14 264.75,-793.29 268.36,-787.3"/>
# </g>
# <!-- Планирование интервью -->
# <g id="node12" class="node">
# <title>Планирование интервью</title>
# <polygon fill="lightgrey" stroke="black" points="334.12,-690.5 171.88,-690.5 171.88,-633 334.12,-633 334.12,-690.5"/>
# <text text-anchor="middle" x="253" y="-673.2" font-family="Times,serif" font-size="14.00">Планирование интервью</text>
# <text text-anchor="middle" x="253" y="-656.7" font-family="Times,serif" font-size="14.00">count: 416</text>
# <text text-anchor="middle" x="253" y="-640.2" font-family="Times,serif" font-size="14.00">mean_duration: 0.026</text>
# </g>
# <!-- Рассмотрение заказчиком&#45;&gt;Планирование интервью -->
# <g id="edge35" class="edge">
# <title>Рассмотрение заказчиком&#45;&gt;Планирование интервью</title>
# <path fill="none" stroke="black" d="M351.15,-819.78C340.83,-794.53 324.08,-756.81 305,-726.5 299.24,-717.35 292.34,-708.04 285.48,-699.46"/>
# <polygon fill="black" stroke="black" points="288.4,-697.5 279.35,-691.99 282.99,-701.94 288.4,-697.5"/>
# </g>
# <!-- Оценка кандидата&#45;&gt;Отклонен -->
# <g id="edge31" class="edge">
# <title>Оценка кандидата&#45;&gt;Отклонен</title>
# <path fill="none" stroke="black" d="M476.83,-726.15C498.2,-694.28 533.14,-642.14 556.83,-606.8"/>
# <polygon fill="black" stroke="black" points="559.69,-608.82 562.35,-598.57 553.88,-604.92 559.69,-608.82"/>
# </g>
# <!-- endevent -->
# <g id="node19" class="node">
# <title>endevent</title>
# <ellipse fill="red" stroke="black" cx="630" cy="-18" rx="18" ry="18"/>
# </g>
# <!-- Отклонен&#45;&gt;endevent -->
# <g id="edge3" class="edge">
# <title>Отклонен&#45;&gt;endevent</title>
# <path fill="none" stroke="black" d="M582,-539.04C582,-502.77 582,-437.81 582,-382.25 582,-382.25 582,-382.25 582,-193.25 582,-138.7 583.43,-123.64 601,-72 604.32,-62.26 609.35,-52.2 614.3,-43.5"/>
# <polygon fill="black" stroke="black" points="617.27,-45.35 619.39,-34.97 611.26,-41.76 617.27,-45.35"/>
# </g>
# <!-- Интервью&#45;&gt;Интервью -->
# <g id="edge41" class="edge">
# <title>Интервью&#45;&gt;Интервью</title>
# <path fill="none" stroke="black" d="M278.48,-771.24C288.91,-768.8 296,-763.47 296,-755.25 296,-750.24 293.37,-746.31 288.95,-743.45"/>
# <polygon fill="black" stroke="black" points="290.47,-740.28 279.88,-739.83 287.87,-746.78 290.47,-740.28"/>
# </g>
# <!-- Заполнение анкеты -->
# <g id="node5" class="node">
# <title>Заполнение анкеты</title>
# <polygon fill="lightgrey" stroke="black" points="136,-690.5 0,-690.5 0,-633 136,-633 136,-690.5"/>
# <text text-anchor="middle" x="68" y="-673.2" font-family="Times,serif" font-size="14.00">Заполнение анкеты</text>
# <text text-anchor="middle" x="68" y="-656.7" font-family="Times,serif" font-size="14.00">count: 417</text>
# <text text-anchor="middle" x="68" y="-640.2" font-family="Times,serif" font-size="14.00">mean_duration: 0.025</text>
# </g>
# <!-- Интервью&#45;&gt;Заполнение анкеты -->
# <g id="edge37" class="edge">
# <title>Интервью&#45;&gt;Заполнение анкеты</title>
# <path fill="none" stroke="black" d="M166.24,-726.05C151.93,-716.83 135.89,-706.49 120.98,-696.89"/>
# <polygon fill="black" stroke="black" points="122.95,-693.99 112.65,-691.52 119.16,-699.88 122.95,-693.99"/>
# </g>
# <!-- Интервью&#45;&gt;Планирование интервью -->
# <g id="edge19" class="edge">
# <title>Интервью&#45;&gt;Планирование интервью</title>
# <path fill="none" stroke="black" d="M216.86,-726.3C220.17,-718.3 224.2,-709.45 228.38,-700.95"/>
# <polygon fill="black" stroke="black" points="231.42,-702.69 232.83,-692.19 225.18,-699.52 231.42,-702.69"/>
# </g>
# <!-- Заполнение анкеты&#45;&gt;Заполнение анкеты -->
# <g id="edge42" class="edge">
# <title>Заполнение анкеты&#45;&gt;Заполнение анкеты</title>
# <path fill="none" stroke="black" d="M136.48,-677.74C146.91,-675.3 154,-669.97 154,-661.75 154,-656.74 151.37,-652.81 146.95,-649.95"/>
# <polygon fill="black" stroke="black" points="148.47,-646.78 137.88,-646.33 145.87,-653.28 148.47,-646.78"/>
# </g>
# <!-- Проверка -->
# <g id="node6" class="node">
# <title>Проверка</title>
# <polygon fill="lightgrey" stroke="black" points="328.62,-597 199.38,-597 199.38,-539.5 328.62,-539.5 328.62,-597"/>
# <text text-anchor="middle" x="264" y="-579.7" font-family="Times,serif" font-size="14.00">Проверка</text>
# <text text-anchor="middle" x="264" y="-563.2" font-family="Times,serif" font-size="14.00">count: 201</text>
# <text text-anch

# %%
from sberpm.autoinsights import AutoInsights

auto_insights = AutoInsights(data_holder)

auto_insights.apply()

bool_insights = auto_insights.bool_insights()
print("Проблемные этапы (True - есть проблема):")
display(bool_insights)

float_insights = auto_insights.float_insights()
print("Оценка серьёзности проблем:")
display(float_insights)

summary = auto_insights.fin_effects_summary()
print("Выявленные проблемы в процессе найма:")
print(summary)
# Out:
# Проблемные этапы (True - есть проблема):
# Метрика                       Длительность операции              \
# Операция                         Растет со временем Bottle neck
# Рассмотрение заказчиком                       False       False
# Оценка кандидата                               True       False
# Отклонен                                      False       False
# Интервью                                       True       False
# Заполнение анкеты                              True       False
# Проверка                                       True       False
# Решение о найме                               False       False
# Согласование офера в компании                 False       False
# Готов к оформлению                             True       False
# Оформление                                     True       False
# Оформлен                                      False       False
# Планирование интервью                         False       False
# Рассмотрение рекрутером                        True       False
# Готов к переводу                              False       False
# Не выходит на связь                           False       False
# Резерв                                         True       False
# Самоотказ                                      True       False
#
# Метрика                                                                  \
# Операция                      Нестандартизированная или ручная операция
# Рассмотрение заказчиком                                           False
# Оценка кандидата                                                  False
# Отклонен                                                          False
# Интервью                                                          False
# Заполнение анкеты                                                 False
# Проверка                                                          False
# Решение о найме                                                   False
# Согласование офера в компании                                     False
# Готов к оформлению                                                False
# Оформление                                                        False
# Оформлен                                                          False
# Планирование интервью                                             False
# Рассмотрение рекрутером                                           False
# Готов к переводу                                                  False
# Не выходит на связь                                               False
# Резерв                                                            False
# Самоотказ                                                         False
#
# Метрика                                                                 \
# Операция                      Разовые инциденты Многократные инциденты
# Рассмотрение заказчиком                   False                  False
# Оценка кандидата                          False                  False
# Отклонен                                  False                  False
# Интервью                                  False                  False
# Заполнение анкеты                         False                  False
# Проверка                                  False                  False
# Решение о найме                           False                  False
# Согласование офера в компании             False                  False
# Готов к оформлению                        False                  False
# Оформление                                False                  False
# Оформлен                                  False                  False
# Планирование интервью                     False                  False
# Рассмотрение рекрутером                   False                  False
# Готов к переводу                          False                  False
# Не выходит на связь                       False                  False
# Резерв                                    False                  False
# Самоотказ                                 False                  False
#
# Метрика                       Длительность процесса                 \
# Операция                      Нерегулярная операция Ошибки системы
# Рассмотрение заказчиком                       False          False
# Оценка кандидата                              False          False
# Отклонен                                      False          False
# Интервью                                      False          False
# Заполнение анкеты                             False          False
# Проверка                                      False          False
# Решение о найме                               False          False
# Согласование офера в компании                 False          False
# Готов к оформлению                            False          False
# Оформление                                    False          False
# Оформлен                                      False          False
# Планирование интервью                         False          False
# Рассмотрение рекрутером                       False          False
# Готов к переводу                               True          False
# Не выходит на связь                            True          False
# Резерв                                         True          False
# Самоотказ                                     False          False
#
# Метрика                                                     Неуспех  \
# Операция                      Возвраты и исправления Ошибки системы
# Рассмотрение заказчиком                        False          False
# Оценка кандидата                               False          False
# Отклонен                                       False          False
# Интервью                                       False          False
# Заполнение анкеты                              False          False
# Проверка                                       False          False
# Решение о найме                                False          False
# Согласование офера в компании                  False          False
# Готов к оформлению                             False          False
# Оформление                                     False          False
# Оформлен                                       False          False
# Планирование интервью                          False          False
# Рассмотрение рекрутером                        False          False
# Готов к переводу                               False          False
# Не выходит на связь                            False          False
# Резерв                                         False          False
# Самоотказ                                      False          False
#
# Метрика                                                                   \
# Операция                      Возвраты и исправления Структурные причины
# Рассмотрение заказчиком                        False               False
# Оценка кандидата                               False               False
# Отклонен                                       False               False
# Интервью                                       False               False
# Заполнение анкеты                              False               False
# Проверка                                       False               False
# Решение о найме                                False               False
# Согласование офера в компании                  False               False
# Готов к оформлению                             False               False
# Оформление                                     False               False
# Оформлен                                       False               False
# Планирование интервью                          False               False
# Рассмотрение рекрутером                        False               False
# Готов к переводу                               False               False
# Не выходит на связь                            False               False
# Резерв                                         False               False
# Самоотказ                                      False               False
#
# Метрика                       Зацикленность                               \
# Операция                           В начало В себя «Возврат» «Пинг-Понг»
# Рассмотрение заказчиком                True  False     False       False
# Оценка кандидата                       True  False     False       False
# Отклонен                               True  False     False       False
# Интервью                               True   True      True        True
# Заполнение анкеты                      True   True      True        True
# Проверка                               True  False     False       False
# Решение о найме                        True  False     False       False
# Согласование офера в компании          True  False     False       False
# Готов к оформлению                     True  False     False       False
# Оформление                             True  False     False       False
# Оформлен                               True  False     False       False
# Планирование интервью                  True  False      True        True
# Рассмотрение рекрутером                True  False      True        True
# Готов к переводу                       True  False     False       False
# Не выходит на связь                    True  False      True       False
# Резерв                                 True  False      True        True
# Самоотказ                              True  False     False       False
#
# Метрика
# Операция                      В произвольную операцию
# Рассмотрение заказчиком                          True
# Оценка кандидата                                 True
# Отклонен                                         True
# Интервью                                         True
# Заполнение анкеты                                True
# Проверка                                         True
# Решение о найме                                  True
# Согласование офера в компании                    True
# Готов к оформлению                               True
# Оформление                                       True
# Оформлен                                         True
# Планирование интервью                            True
# Рассмотрение рекрутером                          True
# Готов к переводу                                 True
# Не выходит на связь                              True
# Резерв                                           True
# Самоотказ                                        True
# Оценка серьёзности проблем:
# Метрика                       Длительность операции              \
# Операция                         Растет со временем Bottle neck
# Рассмотрение заказчиком                    0.000000    0.459356
# Оценка кандидата                           0.001516    0.000000
# Отклонен                                   0.000935    1.000000
# Интервью                                   0.000948    0.434636
# Заполнение анкеты                          0.000948    0.421379
# Проверка                                   0.000959    0.000000
# Решение о найме                            0.000692    0.000000
# Согласование офера в компании              0.000946    0.496747
# Готов к оформлению                         0.001026    0.000000
# Оформление                                 0.000993    0.507137
# Оформлен                                   0.000947    0.768538
# Планирование интервью                      0.000947    0.586357
# Рассмотрение рекрутером                    1.000000    0.986984
# Готов к переводу                           0.000944    0.521946
# Не выходит на связь                        0.000948    0.565154
# Резерв                                     0.000950    0.564622
# Самоотказ                                  0.000949    0.624677
#
# Метрика                                                                  \
# Операция                      Нестандартизированная или ручная операция
# Рассмотрение заказчиком                                        0.952314
# Оценка кандидата                                               0.000000
# Отклонен                                                       0.273456
# Интервью                                                       0.983355
# Заполнение анкеты                                              1.000000
# Проверка                                                       0.000000
# Решение о найме                                                0.000000
# Согласование офера в компании                                  0.905365
# Готов к оформлению                                             0.000000
# Оформление                                                     0.892319
# Оформлен                                                       0.564091
# Планирование интервью                                          0.792846
# Рассмотрение рекрутером                                        0.289800
# Готов к переводу                                               0.873723
# Не выходит на связь                                            0.819470
# Резерв                                                         0.820138
# Самоотказ                                                      0.744730
#
# Метрика                                                                 \
# Операция                      Разовые инциденты Многократные инциденты
# Рассмотрение заказчиком                0.134950               0.459356
# Оценка кандидата                       0.068269               0.000000
# Отклонен                               0.061983               1.000000
# Интервью                               0.143937               0.434636
# Заполнение анкеты                      1.000000               0.421379
# Проверка                               0.367450               0.000000
# Решение о найме                        0.000000               0.000000
# Согласование офера в компании          0.053714               0.496747
# Готов к оформлению                     0.280407               0.000000
# Оформление                             0.066383               0.507137
# Оформлен                               0.146954               0.768538
# Планирование интервью                  0.298137               0.586357
# Рассмотрение рекрутером                0.409745               0.986984
# Готов к переводу                       0.062604               0.521946
# Не выходит на связь                    0.359719               0.565154
# Резерв                                 0.710191               0.564622
# Самоотказ                              0.058505               0.624677
#
# Метрика                       Длительность процесса                 \
# Операция                      Нерегулярная операция Ошибки системы
# Рассмотрение заказчиком                    0.279887            0.0
# Оценка кандидата                           0.725738            0.0
# Отклонен                                   0.000000            0.0
# Интервью                                   0.680731            0.0
# Заполнение анкеты                          0.797468            0.0
# Проверка                                   0.797468            0.0
# Решение о найме                            0.797468            0.0
# Согласование офера в компании              0.797468            0.0
# Готов к оформлению                         0.797468            0.0
# Оформление                                 0.797468            0.0
# Оформлен                                   0.753868            0.0
# Планирование интервью                      0.634318            0.0
# Рассмотрение рекрутером                    0.385373            0.0
# Готов к переводу                           0.977496            0.0
# Не выходит на связь                        0.977496            0.0
# Резерв                                     1.000000            0.0
# Самоотказ                                  0.953586            0.0
#
# Метрика                                                     Неуспех  \
# Операция                      Возвраты и исправления Ошибки системы
# Рассмотрение заказчиком                          0.0            0.0
# Оценка кандидата                                 0.0            0.0
# Отклонен                                         0.0            0.0
# Интервью                                         0.0            0.0
# Заполнение анкеты                                0.0            0.0
# Проверка                                         0.0            0.0
# Решение о найме                                  0.0            0.0
# Согласование офера в компании                    0.0            0.0
# Готов к оформлению                               0.0            0.0
# Оформление                                       0.0            0.0
# Оформлен                                         0.0            0.0
# Планирование интервью                            0.0            0.0
# Рассмотрение рекрутером                          0.0            0.0
# Готов к переводу                                 0.0            0.0
# Не выходит на связь                              0.0            0.0
# Резерв                                           0.0            0.0
# Самоотказ                                        0.0            0.0
#
# Метрика                                                                   \
# Операция                      Возвраты и исправления Структурные причины
# Рассмотрение заказчиком                          0.0                 0.0
# Оценка кандидата                                 0.0                 0.0
# Отклонен                                         0.0                 0.0
# Интервью                                         0.0                 0.0
# Заполнение анкеты                                0.0                 0.0
# Проверка                                         0.0                 0.0
# Решение о найме                                  0.0                 0.0
# Согласование офера в компании                    0.0                 0.0
# Готов к оформлению                               0.0                 0.0
# Оформление                                       0.0                 0.0
# Оформлен                                         0.0                 0.0
# Планирование интервью                            0.0                 0.0
# Рассмотрение рекрутером                          0.0                 0.0
# Готов к переводу                                 0.0                 0.0
# Не выходит на связь                              0.0                 0.0
# Резерв                                           0.0                 0.0
# Самоотказ                                        0.0                 0.0
#
# Метрика                       Зацикленность                                  \
# Операция                           В начало    В себя «Возврат» «Пинг-Понг»
# Рассмотрение заказчиком            0.000000  0.000000  0.000000    0.000000
# Оценка кандидата                   0.047148  0.000000  0.000000    0.000000
# Отклонен                           0.046202  0.000000  0.000000    0.000000
# Интервью                           0.033460  1.000000  1.000000    1.000000
# Заполнение анкеты                  0.059783  0.989766  0.652732    0.485582
# Проверка                           0.062514  0.000000  0.000000    0.000000
# Решение о найме                    0.062514  0.000000  0.000000    0.000000
# Согласование офера в компании      0.062514  0.000000  0.000000    0.000000
# Готов к оформлению                 0.062514  0.000000  0.000000    0.000000
# Оформление                         0.062514  0.000000  0.000000    0.000000
# Оформлен                           0.052369  0.000000  0.000000    0.000000
# Планирование интервью              0.041617  0.000000  0.240733    0.545159
# Рассмотрение рекрутером            0.106282  0.000000  0.070489    0.007941
# Готов к переводу                   0.091116  0.000000  0.000000    0.000000
# Не выходит на связь                0.377891  0.000000  0.131683    0.000000
# Резерв                             1.000000  0.000000  0.240733    0.063277
# Самоотказ                          0.113763  0.000000  0.000000    0.000000
#
# Метрика
# Операция                      В произвольную операцию Уровень аномальности
# Рассмотрение заказчиком                      1.000000             0.360545
# Оценка кандидата                             1.000000             0.000000
# Отклонен                                     1.000000             0.384707
# Интервью                                     0.133773             1.000000
# Заполнение анкеты                            0.000000             0.995894
# Проверка                                     1.000000             0.096362
# Решение о найме                              1.000000             0.004497
# Согласование офера в компании                1.000000             0.492362
# Готов к оформлению                           1.000000             0.074633
# Оформление                                   1.000000             0.497471
# Оформлен                                     1.000000             0.552771
# Планирование интервью                        0.316543             0.549701
# Рассмотрение рекрутером                      0.881070             0.819924
# Готов к переводу                             1.000000             0.551390
# Не выходит на связь                          0.756993             0.677485
# Резерв                                       0.585369             0.926159
# Самоотказ                                    1.000000             0.569155
# Выявленные проблемы в процессе найма:
#
#                     Длительность следующих этапов увеличивается со временем, что может привести в дальнейшем к проблемам в процессе: «Оценка кандидата», «Интервью», «Заполнение анкеты», «Проверка», «Готов к оформлению», «Оформление», «Рассмотрение рекрутером», «Резерв», «Самоотказ».
#
#
#                     Следующие этапы являются нерегулярными (редкими) и не требуются для успешной реализации процесса: «Готов к переводу», «Не выходит на связь», «Резерв». Максимальный потенциальный финансовый эффект при отказе от данных этапов 1617,66 рублей.
#
#
#                     На следующих этапах наблюдается зацикленность, при которой экземпляр процесса начинается и заканчивается на один и тот же этап: «Рассмотрение заказчиком», «Оценка кандидата», «Отклонен», «Интервью», «Заполнение анкеты», «Проверка», «Решение о найме», «Согласование офера в компании», «Готов к оформлению», «Оформление», «Оформлен», «Планирование интервью», «Рассмотрение рекрутером», «Готов к переводу», «Не выходит на связь», «Резерв», «Самоотказ». Максимальный потенциальный финансовый эффект 0,0 рублей.
#
#
#                     На следующих этапах наблюдается зацикленность этапа самого в себя: «Интервью», «Заполнение анкеты». Максимальный потенциальный финансовый эффект 1639,68 рублей.
#
#
#                     На следующих этапах наблюдается зацикленность типа «Возврат»: «Интервью», «Заполнение анкеты», «Планирование интервью», «Рассмотрение рекрутером», «Не выходит на связь», «Резерв». Максимальный потенциальный финансовый эффект 1239,83 рублей.
#
#
#                     На следующих этапах наблюдается зацикленность типа «Пинг-Понг»: «Интервью», «Заполнение анкеты», «Планирование интервью», «Рассмотрение рекрутером», «Резерв». Максимальный потенциальный финансовый эффект 462,71 рублей.
#
#
#                     На следующих этапах наблюдается зацикленность процесса: «Рассмотрение заказчиком», «Оценка кандидата», «Отклонен», «Интервью», «Заполнение анкеты», «Проверка», «Решение о найме», «Согласование офера в компании», «Готов к оформлению», «Оформление», «Оформлен», «Планирование интервью», «Рассмотрение рекрутером», «Готов к переводу», «Не выходит на связь», «Резерв», «Самоотказ». Максимальный потенциальный финансовый эффект от устранения зацикленности 18584,62 рублей.
#
#                 Суммарный финансовый эффект от устранения обнаруженных кейсов неэффективности: 47089,01 рублей.

# %%
from sberpm.metrics import ActivityMetric

activity_metric = ActivityMetric(data_holder)
activity_probs = activity_metric.apply()

activity_df = activity_probs.reset_index()[["index", "probability"]]
activity_df.columns = ["stage", "probability"]

# %%
from sklearn.svm import OneClassSVM

X = activity_df["probability"].values.reshape(-1, 1) 
svm = OneClassSVM(nu=0.1, kernel="rbf")
svm.fit(X)

activity_df["anomaly"] = svm.predict(X)
anomalous_stages = activity_df[activity_df["anomaly"] == -1]["stage"].tolist()

print("Аномальные этапы:", anomalous_stages)

successful_cases = data_holder.data.groupby("case_id")["to"].apply(set)

cases_without_anomalies = successful_cases.apply(lambda stages: all(stage not in stages for stage in anomalous_stages))

successful_without_anomalies = successful_cases[cases_without_anomalies]
print("Количество успешных экземпляров без аномальных этапов:", len(successful_without_anomalies))
# Out:
# Аномальные этапы: ['Интервью', 'Отклонен', 'Планирование интервью']
# Количество успешных экземпляров без аномальных этапов: 31

# %%
from sberpm.imitation import Simulation

gen_holder = DataHolder(
    data=df, 
    col_case="case_id", 
    col_stage="to",
    col_start_time="start_time",
    col_end_time="end_time",
    col_duration="time",
    time_format="%Y-%m-%d %H:%M:%S"
)

simulation_original = Simulation(gen_holder)
simulation_original.generate()
# Out:
# ℹ️ INFO     | sberpm.baza._sota_utils:	Чтение данных...
#
# ℹ️ INFO     | sberpm.baza.holder:	Обработка данных ивент лога...
#
# ℹ️ INFO     | sberpm.baza._data_processing:	Определяем пропуски в текстовых данных...
#
# ℹ️ INFO     | sberpm.baza._data_processing:	Данные будут отсортированы по следующим колонкам: ['case_id', 'start_time', 'end_time', 'to']
#
# ℹ️ INFO     | sberpm.baza._data_processing:	Производится оптимизация типов данных...
#
# ℹ️ INFO     | sberpm.baza.holder:	Обработка данных завершена
#   0%|          | 0/99 [00:00<?, ?it/s]

# %%
from sberpm.visual import Graph

def show_graph(graph: Graph, save=True, filename="graph", **kwargs):
    if kwargs.get("happy_path"):
        painter.apply_happy_path(graph, kwargs["happy_path"])
    elif kwargs.get("auto_insights"):
        painter.apply_insights(graph, **kwargs["auto_insights"])
    else:
        painter.apply(graph, **kwargs)

    display(painter.show())

# %%
from sberpm.metrics import TransitionMetric

as_is_miner = SimpleMiner(gen_holder)
as_is_miner.apply()

node_mean_duration = ActivityMetric(gen_holder, time_unit="second").mean_duration().round(2).to_dict()
edge_mean_duration = TransitionMetric(gen_holder, time_unit="second").mean_duration().round(2).to_dict()

as_is_graph = as_is_miner.graph
as_is_graph.add_node_metric("mean_time", node_mean_duration)

show_graph(as_is_graph, filename="Simulation_as-is", node_style_metric="mean_time", edge_style_metric="mean_time")
# Out:
# WARNING: graph does not contain edge metric "mean_time". Edges will have the same width.
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 12.2.1 (20241206.2353)
#  -->
# <!-- Pages: 1 -->
# <svg width="832pt" height="963pt"
#  viewBox="0.00 0.00 831.85 963.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 959)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-959 827.85,-959 827.85,4 -4,4"/>
# <!-- Рассмотрение заказчиком -->
# <g id="node1" class="node">
# <title>Рассмотрение заказчиком</title>
# <polygon fill="#cdcdcd" stroke="black" points="428.38,-729 261.62,-729 261.62,-688 428.38,-688 428.38,-729"/>
# <text text-anchor="middle" x="345" y="-711.7" font-family="Times,serif" font-size="14.00">Рассмотрение заказчиком</text>
# <text text-anchor="middle" x="345" y="-695.2" font-family="Times,serif" font-size="14.00">mean_time: 338.95</text>
# </g>
# <!-- Оценка кандидата -->
# <g id="node2" class="node">
# <title>Оценка кандидата</title>
# <polygon fill="#cfcfcf" stroke="black" points="506.25,-652 383.75,-652 383.75,-611 506.25,-611 506.25,-652"/>
# <text text-anchor="middle" x="445" y="-634.7" font-family="Times,serif" font-size="14.00">Оценка кандидата</text>
# <text text-anchor="middle" x="445" y="-618.2" font-family="Times,serif" font-size="14.00">mean_time: 320.22</text>
# </g>
# <!-- Рассмотрение заказчиком&#45;&gt;Оценка кандидата -->
# <g id="edge21" class="edge">
# <title>Рассмотрение заказчиком&#45;&gt;Оценка кандидата</title>
# <path fill="none" stroke="black" d="M371.54,-687.6C383.06,-678.95 396.74,-668.69 409.15,-659.39"/>
# <polygon fill="black" stroke="black" points="411.23,-662.2 417.13,-653.4 407.03,-656.6 411.23,-662.2"/>
# </g>
# <!-- Отклонен -->
# <g id="node3" class="node">
# <title>Отклонен</title>
# <polygon fill="#c2c2c2" stroke="black" points="623.25,-498 500.75,-498 500.75,-457 623.25,-457 623.25,-498"/>
# <text text-anchor="middle" x="562" y="-480.7" font-family="Times,serif" font-size="14.00">Отклонен</text>
# <text text-anchor="middle" x="562" y="-464.2" font-family="Times,serif" font-size="14.00">mean_time: 412.19</text>
# </g>
# <!-- Рассмотрение заказчиком&#45;&gt;Отклонен -->
# <g id="edge22" class="edge">
# <title>Рассмотрение заказчиком&#45;&gt;Отклонен</title>
# <path fill="none" stroke="black" d="M347.35,-687.71C350.63,-666.94 358.2,-634.14 375,-611 409.66,-563.26 466.9,-526.37 508.94,-503.78"/>
# <polygon fill="black" stroke="black" points="510.45,-506.94 517.67,-499.19 507.19,-500.75 510.45,-506.94"/>
# </g>
# <!-- Интервью -->
# <g id="node4" class="node">
# <title>Интервью</title>
# <polygon fill="#e4e4e4" stroke="black" points="272.25,-652 149.75,-652 149.75,-611 272.25,-611 272.25,-652"/>
# <text text-anchor="middle" x="211" y="-634.7" font-family="Times,serif" font-size="14.00">Интервью</text>
# <text text-anchor="middle" x="211" y="-618.2" font-family="Times,serif" font-size="14.00">mean_time: 176.04</text>
# </g>
# <!-- Рассмотрение заказчиком&#45;&gt;Интервью -->
# <g id="edge11" class="edge">
# <title>Рассмотрение заказчиком&#45;&gt;Интервью</title>
# <path fill="none" stroke="black" d="M309.44,-687.6C293.24,-678.53 273.86,-667.68 256.6,-658.02"/>
# <polygon fill="black" stroke="black" points="258.48,-655.06 248.04,-653.23 255.06,-661.17 258.48,-655.06"/>
# </g>
# <!-- Планирование интервью -->
# <g id="node12" class="node">
# <title>Планирование интервью</title>
# <polygon fill="#f0f0f0" stroke="black" points="328.12,-575 165.88,-575 165.88,-534 328.12,-534 328.12,-575"/>
# <text text-anchor="middle" x="247" y="-557.7" font-family="Times,serif" font-size="14.00">Планирование интервью</text>
# <text text-anchor="middle" x="247" y="-541.2" font-family="Times,serif" font-size="14.00">mean_time: 94.1</text>
# </g>
# <!-- Рассмотрение заказчиком&#45;&gt;Планирование интервью -->
# <g id="edge35" class="edge">
# <title>Рассмотрение заказчиком&#45;&gt;Планирование интервью</title>
# <path fill="none" stroke="black" d="M337.66,-687.69C329.69,-667.49 315.84,-635.68 299,-611 292.41,-601.35 284.17,-591.74 276.19,-583.29"/>
# <polygon fill="black" stroke="black" points="278.93,-581.08 269.44,-576.36 273.91,-585.97 278.93,-581.08"/>
# </g>
# <!-- Оценка кандидата&#45;&gt;Отклонен -->
# <g id="edge31" class="edge">
# <title>Оценка кандидата&#45;&gt;Отклонен</title>
# <path fill="none" stroke="black" d="M460.3,-610.63C480.62,-584.23 516.65,-537.41 539.92,-507.18"/>
# <polygon fill="black" stroke="black" points="542.45,-509.63 545.78,-499.58 536.9,-505.37 542.45,-509.63"/>
# </g>
# <!-- endevent -->
# <g id="node19" class="node">
# <title>endevent</title>
# <ellipse fill="red" stroke="black" cx="605" cy="-18" rx="18" ry="18"/>
# </g>
# <!-- Отклонен&#45;&gt;endevent -->
# <g id="edge3" class="edge">
# <title>Отклонен&#45;&gt;endevent</title>
# <path fill="none" stroke="black" d="M562,-456.82C562,-427.85 562,-372 562,-324.5 562,-324.5 562,-324.5 562,-168.5 562,-124.79 567.67,-113.63 581,-72 583.94,-62.8 588.04,-53.08 592.01,-44.51"/>
# <polygon fill="black" stroke="black" points="595.04,-46.29 596.23,-35.76 588.73,-43.25 595.04,-46.29"/>
# </g>
# <!-- Интервью&#45;&gt;Интервью -->
# <g id="edge41" class="edge">
# <title>Интервью&#45;&gt;Интервью</title>
# <path fill="none" stroke="black" d="M272.47,-644.98C282.97,-643.14 290.25,-638.64 290.25,-631.5 290.25,-627.26 287.69,-623.95 283.4,-621.58"/>
# <polygon fill="black" stroke="black" points="284.5,-618.26 273.91,-618.49 282.34,-624.91 284.5,-618.26"/>
# </g>
# <!-- Заполнение анкеты -->
# <g id="node5" class="node">
# <title>Заполнение анкеты</title>
# <polygon fill="#f0f0f0" stroke="black" points="130,-575 0,-575 0,-534 130,-534 130,-575"/>
# <text text-anchor="middle" x="65" y="-557.7" font-family="Times,serif" font-size="14.00">Заполнение анкеты</text>
# <text text-anchor="middle" x="65" y="-541.2" font-family="Times,serif" font-size="14.00">mean_time: 89.45</text>
# </g>
# <!-- Интервью&#45;&gt;Заполнение анкеты -->
# <g id="edge37" class="edge">
# <title>Интервью&#45;&gt;Заполнение анкеты</title>
# <path fill="none" stroke="black" d="M172.26,-610.6C154.44,-601.44 133.1,-590.48 114.16,-580.75"/>
# <polygon fill="black" stroke="black" points="115.76,-577.64 105.27,-576.19 112.57,-583.87 115.76,-577.64"/>
# </g>
# <!-- Интервью&#45;&gt;Планирование интервью -->
# <g id="edge19" class="edge">
# <title>Интервью&#45;&gt;Планирование интервью</title>
# <path fill="none" stroke="black" d="M214.44,-610.79C217.48,-603.02 221.65,-593.91 226.04,-585.36"/>
# <polygon fill="black" stroke="black" points="229.07,-587.13 230.73,-576.67 222.9,-583.81 229.07,-587.13"/>
# </g>
# <!-- Заполнение анкеты&#45;&gt;Заполнение анкеты -->
# <g id="edge42" class="edge">
# <title>Заполнение анкеты&#45;&gt;Заполнение анкеты</title>
# <path fill="none" stroke="black" d="M130.41,-567.8C140.85,-565.85 148,-561.42 148,-554.5 148,-550.39 145.48,-547.16 141.25,-544.81"/>
# <polygon fill="black" stroke="black" points="142.44,-541.52 131.85,-541.68 140.23,-548.16 142.44,-541.52"/>
# </g>
# <!-- Проверка -->
# <g id="node6" class="node">
# <title>Проверка</title>
# <polygon fill="#e3e3e3" stroke="black" points="318.25,-498 195.75,-498 195.75,-457 318.25,-457 318.25,-498"/>
# <text text-anchor="middle" x="257" y="-480.7" font-family="Times,serif" font-size="14.00">Проверка</text>
# <text text-anchor="middle" x="257" y="-464.2" font-family="Times,serif" font-size="14.00">mean_time: 179.23</text>
# </g>
# <!-- Заполнение анкеты&#45;&gt;Проверка -->
# <g id="edge8" class="edge">
# <title>Заполнение анкеты&#45;&gt;Проверка</title>
# <path fill="none" stroke="black" d="M115.95,-533.6C140.25,-524.11 169.53,-512.67 195.11,-502.68"/>
# <polygon fill="black" stroke="black" points="196.36,-505.94 204.4,-499.05 193.82,-499.42 196.36,-505.94"/>
# </g>
# <!-- Решение о найме -->
# <g id="node7" class="node">
# <title>Решение о найме</title>
# <polygon fill="#c4c4c4" stroke="black" points="485.25,-421 362.75,-421 362.75,-380 485.25,-380 485.25,-421"/>
# <text text-anchor="middle" x="424" y="-403.7" font-family="Times,serif" font-size="14.00">Решение о найме</text>
# <text text-anchor="middle" x="424" y="-387.2

# %%
simulation_optimized = Simulation(gen_holder)

# 1. Снижение длительности проблемных этапов на 20%
problematic_stages = [
    "Оценка кандидата", "Интервью", "Заполнение анкеты", "Проверка", "Готов к оформлению", 
    "Оформление", "Рассмотрение рекрутером", "Резерв", "Самоотказ"
]
for stage in problematic_stages:
    simulation_optimized.scale_time_node(stage, scale=0.8)

# 2. Удаление нерегулярных этапов
excluded_stages = ["Готов к переводу", "Не выходит на связь", "Резерв"]
for stage in excluded_stages:
    simulation_optimized.delete_node(stage)

# 3. Устранение зацикливаний (ограничение повторов)
for stage in ["Интервью", "Заполнение анкеты"]:
    simulation_optimized.delete_loop(stage)

simulation_optimized.generate()

original_duration = simulation_original.get_result()["time"].mean()
optimized_duration = simulation_optimized.get_result()["time"].mean()

print(f"Исходная средняя длительность процесса: {original_duration:.2f} часов")
print(f"Оптимизированная средняя длительность процесса: {optimized_duration:.2f} часов")

optimized_miner = SimpleMiner(gen_holder)
optimized_miner.apply()
node_mean_duration_opt = ActivityMetric(gen_holder, time_unit="second").mean_duration().round(2).to_dict()
edge_mean_duration_opt = TransitionMetric(gen_holder, time_unit="second").mean_duration().round(2).to_dict()
optimized_graph = optimized_miner.graph
optimized_graph.add_node_metric("mean_time", node_mean_duration_opt)
show_graph(optimized_graph, filename="Simulation_optimized", node_style_metric="mean_time", edge_style_metric="mean_time")
# Out:
#   0%|          | 0/99 [00:00<?, ?it/s]
# Исходная средняя длительность процесса: 346.94 часов
# Оптимизированная средняя длительность процесса: 277.89 часов
# WARNING: graph does not contain edge metric "mean_time". Edges will have the same width.
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 12.2.1 (20241206.2353)
#  -->
# <!-- Pages: 1 -->
# <svg width="832pt" height="963pt"
#  viewBox="0.00 0.00 831.85 963.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 959)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-959 827.85,-959 827.85,4 -4,4"/>
# <!-- Рассмотрение заказчиком -->
# <g id="node1" class="node">
# <title>Рассмотрение заказчиком</title>
# <polygon fill="#cdcdcd" stroke="black" points="428.38,-729 261.62,-729 261.62,-688 428.38,-688 428.38,-729"/>
# <text text-anchor="middle" x="345" y="-711.7" font-family="Times,serif" font-size="14.00">Рассмотрение заказчиком</text>
# <text text-anchor="middle" x="345" y="-695.2" font-family="Times,serif" font-size="14.00">mean_time: 338.95</text>
# </g>
# <!-- Оценка кандидата -->
# <g id="node2" class="node">
# <title>Оценка кандидата</title>
# <polygon fill="#cfcfcf" stroke="black" points="506.25,-652 383.75,-652 383.75,-611 506.25,-611 506.25,-652"/>
# <text text-anchor="middle" x="445" y="-634.7" font-family="Times,serif" font-size="14.00">Оценка кандидата</text>
# <text text-anchor="middle" x="445" y="-618.2" font-family="Times,serif" font-size="14.00">mean_time: 320.22</text>
# </g>
# <!-- Рассмотрение заказчиком&#45;&gt;Оценка кандидата -->
# <g id="edge21" class="edge">
# <title>Рассмотрение заказчиком&#45;&gt;Оценка кандидата</title>
# <path fill="none" stroke="black" d="M371.54,-687.6C383.06,-678.95 396.74,-668.69 409.15,-659.39"/>
# <polygon fill="black" stroke="black" points="411.23,-662.2 417.13,-653.4 407.03,-656.6 411.23,-662.2"/>
# </g>
# <!-- Отклонен -->
# <g id="node3" class="node">
# <title>Отклонен</title>
# <polygon fill="#c2c2c2" stroke="black" points="623.25,-498 500.75,-498 500.75,-457 623.25,-457 623.25,-498"/>
# <text text-anchor="middle" x="562" y="-480.7" font-family="Times,serif" font-size="14.00">Отклонен</text>
# <text text-anchor="middle" x="562" y="-464.2" font-family="Times,serif" font-size="14.00">mean_time: 412.19</text>
# </g>
# <!-- Рассмотрение заказчиком&#45;&gt;Отклонен -->
# <g id="edge22" class="edge">
# <title>Рассмотрение заказчиком&#45;&gt;Отклонен</title>
# <path fill="none" stroke="black" d="M347.35,-687.71C350.63,-666.94 358.2,-634.14 375,-611 409.66,-563.26 466.9,-526.37 508.94,-503.78"/>
# <polygon fill="black" stroke="black" points="510.45,-506.94 517.67,-499.19 507.19,-500.75 510.45,-506.94"/>
# </g>
# <!-- Интервью -->
# <g id="node4" class="node">
# <title>Интервью</title>
# <polygon fill="#e4e4e4" stroke="black" points="272.25,-652 149.75,-652 149.75,-611 272.25,-611 272.25,-652"/>
# <text text-anchor="middle" x="211" y="-634.7" font-family="Times,serif" font-size="14.00">Интервью</text>
# <text text-anchor="middle" x="211" y="-618.2" font-family="Times,serif" font-size="14.00">mean_time: 176.04</text>
# </g>
# <!-- Рассмотрение заказчиком&#45;&gt;Интервью -->
# <g id="edge11" class="edge">
# <title>Рассмотрение заказчиком&#45;&gt;Интервью</title>
# <path fill="none" stroke="black" d="M309.44,-687.6C293.24,-678.53 273.86,-667.68 256.6,-658.02"/>
# <polygon fill="black" stroke="black" points="258.48,-655.06 248.04,-653.23 255.06,-661.17 258.48,-655.06"/>
# </g>
# <!-- Планирование интервью -->
# <g id="node12" class="node">
# <title>Планирование интервью</title>
# <polygon fill="#f0f0f0" stroke="black" points="328.12,-575 165.88,-575 165.88,-534 328.12,-534 328.12,-575"/>
# <text text-anchor="middle" x="247" y="-557.7" font-family="Times,serif" font-size="14.00">Планирование интервью</text>
# <text text-anchor="middle" x="247" y="-541.2" font-family="Times,serif" font-size="14.00">mean_time: 94.1</text>
# </g>
# <!-- Рассмотрение заказчиком&#45;&gt;Планирование интервью -->
# <g id="edge35" class="edge">
# <title>Рассмотрение заказчиком&#45;&gt;Планирование интервью</title>
# <path fill="none" stroke="black" d="M337.66,-687.69C329.69,-667.49 315.84,-635.68 299,-611 292.41,-601.35 284.17,-591.74 276.19,-583.29"/>
# <polygon fill="black" stroke="black" points="278.93,-581.08 269.44,-576.36 273.91,-585.97 278.93,-581.08"/>
# </g>
# <!-- Оценка кандидата&#45;&gt;Отклонен -->
# <g id="edge31" class="edge">
# <title>Оценка кандидата&#45;&gt;Отклонен</title>
# <path fill="none" stroke="black" d="M460.3,-610.63C480.62,-584.23 516.65,-537.41 539.92,-507.18"/>
# <polygon fill="black" stroke="black" points="542.45,-509.63 545.78,-499.58 536.9,-505.37 542.45,-509.63"/>
# </g>
# <!-- endevent -->
# <g id="node19" class="node">
# <title>endevent</title>
# <ellipse fill="red" stroke="black" cx="605" cy="-18" rx="18" ry="18"/>
# </g>
# <!-- Отклонен&#45;&gt;endevent -->
# <g id="edge3" class="edge">
# <title>Отклонен&#45;&gt;endevent</title>
# <path fill="none" stroke="black" d="M562,-456.82C562,-427.85 562,-372 562,-324.5 562,-324.5 562,-324.5 562,-168.5 562,-124.79 567.67,-113.63 581,-72 583.94,-62.8 588.04,-53.08 592.01,-44.51"/>
# <polygon fill="black" stroke="black" points="595.04,-46.29 596.23,-35.76 588.73,-43.25 595.04,-46.29"/>
# </g>
# <!-- Интервью&#45;&gt;Интервью -->
# <g id="edge41" class="edge">
# <title>Интервью&#45;&gt;Интервью</title>
# <path fill="none" stroke="black" d="M272.47,-644.98C282.97,-643.14 290.25,-638.64 290.25,-631.5 290.25,-627.26 287.69,-623.95 283.4,-621.58"/>
# <polygon fill="black" stroke="black" points="284.5,-618.26 273.91,-618.49 282.34,-624.91 284.5,-618.26"/>
# </g>
# <!-- Заполнение анкеты -->
# <g id="node5" class="node">
# <title>Заполнение анкеты</title>
# <polygon fill="#f0f0f0" stroke="black" points="130,-575 0,-575 0,-534 130,-534 130,-575"/>
# <text text-anchor="middle" x="65" y="-557.7" font-family="Times,serif" font-size="14.00">Заполнение анкеты</text>
# <text text-anchor="middle" x="65" y="-541.2" font-family="Times,serif" font-size="14.00">mean_time: 89.45</text>
# </g>
# <!-- Интервью&#45;&gt;Заполнение анкеты -->
# <g id="edge37" class="edge">
# <title>Интервью&#45;&gt;Заполнение анкеты</title>
# <path fill="none" stroke="black" d="M172.26,-610.6C154.44,-601.44 133.1,-590.48 114.16,-580.75"/>
# <polygon fill="black" stroke="black" points="115.76,-577.64 105.27,-576.19 112.57,-583.87 115.76,-577.64"/>
# </g>
# <!-- Интервью&#45;&gt;Планирование интервью -->
# <g id="edge19" class="edge">
# <title>Интервью&#45;&gt;Планирование интервью</title>
# <path fill="none" stroke="black" d="M214.44,-610.79C217.48,-603.02 221.65,-593.91 226.04,-585.36"/>
# <polygon fill="black" stroke="black" points="229.07,-587.13 230.73,-576.67 222.9,-583.81 229.07,-587.13"/>
# </g>
# <!-- Заполнение анкеты&#45;&gt;Заполнение анкеты -->
# <g id="edge42" class="edge">
# <title>Заполнение анкеты&#45;&gt;Заполнение анкеты</title>
# <path fill="none" stroke="black" d="M130.41,-567.8C140.85,-565.85 148,-561.42 148,-554.5 148,-550.39 145.48,-547.16 141.25,-544.81"/>
# <polygon fill="black" stroke="black" points="142.44,-541.52 131.85,-541.68 140.23,-548.16 142.44,-541.52"/>
# </g>
# <!-- Проверка -->
# <g id="node6" class="node">
# <title>Проверка</title>
# <polygon fill="#e3e3e3" stroke="black" points="318.25,-498 195.75,-498 195.75,-457 318.25,-457 318.25,-498"/>
# <text text-anchor="middle" x="257" y="-480.7" font-family="Times,serif" font-size="14.00">Проверка</text>
# <text text-anchor="middle" x="257" y="-464.2" font-family="Times,serif" font-size="14.00">mean_time: 179.23</text>
# </g>
# <!-- Заполнение анкеты&#45;&gt;Проверка -->
# <g id="edge8" class="edge">
# <title>Заполнение анкеты&#45;&gt;Проверка</title>
# <path fill="none" stroke="black" d="M115.95,-533.6C140.25,-524.11 169.53,-512.67 195.11,-502.68"/>
# <polygon fill="black" stroke="black" points="196.36,-505.94 204.4,-499.05 193.82,-499.42 196.36,-505.94"/>
# </g>
# <!-- Решение о найме -->
# <g id="node7" class="node">
# <title>Решение о найме</title>
# <polygon fill="#c4c4c4" stroke="black" points="485.25,-421 362.75,-421 362.75,-380 485.25,-380 485.25,-421"/>
# <text text-anchor="middle" x="424" y="-403.7" font-family="Times,serif" font-size="14.00">Решение о найме</text>
# <text text-anchor="middle" x="424" y="-387.2

# %% [markdown]
# RL методы

# %%
class ProcessEnvironment:
    def __init__(self, holder):
        self.holder = holder
        self.actions = holder.unique_stages.tolist()
        self.transition_probabilities = holder.stage.value_counts(normalize=True).to_dict()
        self.state = None

    def reset(self):
        self.state = random.choice(self.actions)
        return self.state

    def step(self, action):
        if action not in self.actions:
            return self.state, -10, True, {}  # Наказание за недопустимое действие

        reward = 0
        loss = self.holder.duration[self.holder.stage == action].mean()  # Потери = средняя длительность

        if action == "Оформлен":
            reward = 20  # Главная цель
        elif self.transition_probabilities.get(action, 0) < 0.05:
            reward = 10  # Редкие полезные переходы
        elif action == self.state:
            reward = -5  # Штраф за зацикливание
        else:
            reward = 1  # Обычный переход
        
        self.state = action  # Обновляем состояние
        return self.state, reward - loss / 10, action == "Оформлен", {}

# %%
class QLearningAgent:
    def __init__(self, env, alpha=0.1, gamma=0.9, epsilon=0.1):
        self.env = env
        self.q_table = {state: {action: 0 for action in env.actions} for state in env.actions}
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon

    def choose_action(self, state):
        if random.uniform(0, 1) < self.epsilon:
            return random.choice(self.env.actions)
        else:
            return max(self.q_table[state], key=self.q_table[state].get, default=random.choice(self.env.actions))

    def train(self, episodes=1000):
        for _ in range(episodes):
            state = self.env.reset()
            done = False
            while not done:
                action = self.choose_action(state)
                next_state, reward, done, _ = self.env.step(action)
                best_next_action = max(self.q_table[next_state], key=self.q_table[next_state].get, default=0)
                self.q_table[state][action] += self.alpha * (reward + self.gamma * self.q_table[next_state][best_next_action] - self.q_table[state][action])
                state = next_state
        return self.q_table

# %%
class CrossEntropyMethod:
    def __init__(self, env, elite_frac=0.2, iterations=50):
        self.env = env
        self.elite_frac = elite_frac
        self.iterations = iterations

    def train(self):
        population = [random.sample(self.env.actions, len(self.env.actions)) for _ in range(100)]
        for _ in range(self.iterations):
            scores = [(self.fitness(seq), seq) for seq in population]
            elite_count = int(len(population) * self.elite_frac)
            elite = [seq for _, seq in sorted(scores, reverse=True)[:elite_count]]
            population = elite + [random.choice(elite) for _ in range(100 - elite_count)]
        return population[0]

    def fitness(self, sequence):
        return sum(self.env.step(action)[1] for action in sequence)

# %%
class GeneticAlgorithm:
    def __init__(self, env, population_size=20, mutation_rate=0.1, generations=50):
        self.env = env
        self.population_size = population_size
        self.mutation_rate = mutation_rate
        self.generations = generations

    def initialize_population(self):
        return [random.sample(self.env.actions, len(self.env.actions)) for _ in range(self.population_size)]

    def fitness(self, sequence):
        return sum(self.env.step(action)[1] for action in sequence)

    def mutate(self, sequence):
        if random.uniform(0, 1) < self.mutation_rate:
            idx1, idx2 = random.sample(range(len(sequence)), 2)
            sequence[idx1], sequence[idx2] = sequence[idx2], sequence[idx1]
        return sequence

    def train(self):
        population = self.initialize_population()
        for _ in range(self.generations):
            population = sorted(population, key=self.fitness, reverse=True)
            new_population = population[:self.population_size // 2]
            while len(new_population) < self.population_size:
                parent1, parent2 = random.sample(population[:10], 2)
                crossover_point = random.randint(1, len(parent1) - 1)
                child = parent1[:crossover_point] + parent2[crossover_point:]
                new_population.append(self.mutate(child))
            population = new_population
        return population[0]

# %%
def train_pipeline(method, env, iterations=1000):
    if method == "qlearning":
        agent = QLearningAgent(env)
    elif method == "crossentropy":
        agent = CrossEntropyMethod(env, iterations=iterations)
    elif method == "genetic":
        agent = GeneticAlgorithm(env, generations=iterations//20)
    else:
        raise ValueError("Unsupported method")
    return agent.train()

# %%
holder = DataHolder(
    data=df,
    col_case="case_id",
    col_stage="to",
    col_start_time="start_time",
    col_end_time="end_time",
    col_duration="time",
    time_format="%Y-%m-%d %H:%M:%S"
)

# Сравнение методов
env = ProcessEnvironment(holder)
methods = ["qlearning", "crossentropy", "genetic"]
results = {}

for method in methods:
    print(f"Training with {method}...")
    results[method] = train_pipeline(method, env)
# Out:
# ℹ️ INFO     | sberpm.baza._sota_utils:	Чтение данных...
#
# ℹ️ INFO     | sberpm.baza.holder:	Обработка данных ивент лога...
#
# ℹ️ INFO     | sberpm.baza._data_processing:	Определяем пропуски в текстовых данных...
#
# ℹ️ INFO     | sberpm.baza._data_processing:	Данные будут отсортированы по следующим колонкам: ['case_id', 'start_time', 'end_time', 'to']
#
# ℹ️ INFO     | sberpm.baza._data_processing:	Производится оптимизация типов данных...
#
# ℹ️ INFO     | sberpm.baza.holder:	Обработка данных завершена
#
# Training with qlearning...
# Training with crossentropy...
# Training with genetic...

# %%
# Выбираем лучший метод
best_method = max(results, key=lambda k: sum(env.step(a)[1] for a in results[k]) / len(results[k]))
print(f"Best method: {best_method}")

# Запускаем симуляцию с лучшим методом
simulation = Simulation(holder)
for i in range(len(results[best_method]) - 1):
    state, next_state = results[best_method][i], results[best_method][i + 1]
    simulation.change_edge_probability(state, next_state, 1.0)

simulation.generate()

# Визуализация графа после обучения
generated_holder = DataHolder(
    data=simulation.get_result(),
    col_case="case_id",
    col_stage="to",
    col_start_time="start_time",
    col_end_time="end_time",
    col_duration="time",
    time_format="%Y-%m-%d %H:%M:%S"
)

optimized_miner = SimpleMiner(generated_holder)
optimized_miner.apply()
node_mean_duration_opt = ActivityMetric(generated_holder, time_unit="second").mean_duration().round(2).to_dict()
edge_mean_duration_opt = TransitionMetric(generated_holder, time_unit="second").mean_duration().round(2).to_dict()
optimized_graph = optimized_miner.graph
optimized_graph.add_node_metric("mean_time", node_mean_duration_opt)
optimized_graph.add_edge_metric("mean_time", edge_mean_duration_opt)

show_graph(optimized_graph, filename="Simulation_optimized", node_style_metric="mean_time", edge_style_metric="mean_time")
# Out:
# Best method: genetic
#   0%|          | 0/99 [00:00<?, ?it/s]
# ℹ️ INFO     | sberpm.baza._sota_utils:	Чтение данных...
#
# ℹ️ INFO     | sberpm.baza.holder:	Обработка данных ивент лога...
#
# ℹ️ INFO     | sberpm.baza._data_processing:	Определяем пропуски в текстовых данных...
#
# ℹ️ INFO     | sberpm.baza._data_processing:	Данные будут отсортированы по следующим колонкам: ['case_id', 'start_time', 'end_time', 'to']
#
# ℹ️ INFO     | sberpm.baza._data_processing:	Производится оптимизация типов данных...
#
# ℹ️ INFO     | sberpm.baza.holder:	Обработка данных завершена
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 12.2.1 (20241206.2353)
#  -->
# <!-- Pages: 1 -->
# <svg width="1064pt" height="1248pt"
#  viewBox="0.00 0.00 1063.50 1248.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 1244)">
# <polygon fill="white" stroke="none" points="-4,4 -4,-1244 1059.5,-1244 1059.5,4 -4,4"/>
# <!-- Рассмотрение рекрутером -->
# <g id="node1" class="node">
# <title>Рассмотрение рекрутером</title>
# <polygon fill="#cbcbcb" stroke="black" points="450.38,-1167 282.12,-1167 282.12,-1126 450.38,-1126 450.38,-1167"/>
# <text text-anchor="middle" x="366.25" y="-1149.7" font-family="Times,serif" font-size="14.00">Рассмотрение рекрутером</text>
# <text text-anchor="middle" x="366.25" y="-1133.2" font-family="Times,serif" font-size="14.00">mean_time: 462.59</text>
# </g>
# <!-- Рассмотрение заказчиком -->
# <g id="node2" class="node">
# <title>Рассмотрение заказчиком</title>
# <polygon fill="#d1d1d1" stroke="black" points="600.62,-1073.5 433.88,-1073.5 433.88,-1032.5 600.62,-1032.5 600.62,-1073.5"/>
# <text text-anchor="middle" x="517.25" y="-1056.2" font-family="Times,serif" font-size="14.00">Рассмотрение заказчиком</text>
# <text text-anchor="middle" x="517.25" y="-1039.7" font-family="Times,serif" font-size="14.00">mean_time: 403.52</text>
# </g>
# <!-- Рассмотрение рекрутером&#45;&gt;Рассмотрение заказчиком -->
# <g id="edge40" class="edge">
# <title>Рассмотрение рекрутером&#45;&gt;Рассмотрение заказчиком</title>
# <path fill="none" stroke="black" stroke-width="0.1" d="M399.01,-1125.65C421.5,-1112.02 451.51,-1093.83 475.68,-1079.19"/>
# <polygon fill="black" stroke="black" stroke-width="0.1" points="477.42,-1082.23 484.16,-1074.05 473.79,-1076.24 477.42,-1082.23"/>
# <text text-anchor="middle" x="463.9" y="-1094.7" font-family="Times,serif" font-size="14.00">0.0</text>
# </g>
# <!-- Оценка кандидата -->
# <g id="node3" class="node">
# <title>Оценка кандидата</title>
# <polygon fill="#d7d7d7" stroke="black" points="122.5,-980 0,-980 0,-939 122.5,-939 122.5,-980"/>
# <text text-anchor="middle" x="61.25" y="-962.7" font-family="Times,serif" font-size="14.00">Оценка кандидата</text>
# <text text-anchor="middle" x="61.25" y="-946.2" font-family="Times,serif" font-size="14.00">mean_time: 348.95</text>
# </g>
# <!-- Рассмотрение рекрутером&#45;&gt;Оценка кандидата -->
# <g id="edge12" class="edge">
# <title>Рассмотрение рекрутером&#45;&gt;Оценка кандидата</title>
# <path fill="none" stroke="black" stroke-width="0.1" d="M281.76,-1139.7C226,-1134.39 159.16,-1124.74 136.25,-1108 96.98,-1079.31 76.85,-1024.06 67.72,-989.93"/>
# <polygon fill="black" stroke="black" stroke-width="0.1" points="71.21,-989.47 65.37,-980.63 64.43,-991.18 71.21,-989.47"/>
# <text text-anchor="middle" x="111.46" y="-1047.95" font-family="Times,serif" font-size="14.00">0.0</text>
# </g>
# <!-- Отклонен -->
# <g id="node4" class="node">
# <title>Отклонен</title>
# <polygon fill="#c9c9c9" stroke="black" points="847.5,-114 725,-114 725,-73 847.5,-73 847.5,-114"/>
# <text text-anchor="middle" x="786.25" y="-96.7" font-family="Times,serif" font-size="14.00">Отклонен</text>
# <text text-anchor="middle" x="786.25" y="-80.2" font-family="Times,serif" font-size="14.00">mean_time: 477.18</text>
# </g>
# <!-- Рассмотрение рекрутером&#45;&gt;Отклонен -->
# <g id="edge13" class="edge">
# <title>Рассмотрение рекрутером&#45;&gt;Отклонен</title>
# <path fill="none" stroke="black" stroke-width="0.1" d="M450.42,-1145.6C555.95,-1144.35 742,-1137.59 898.25,-1108 963.78,-1095.59 1038.25,-1120.69 1038.25,-1054 1038.25,-1054 1038.25,-1054 1038.25,-186 1038.25,-152.99 1016.23,-147.8 987.25,-132 947.6,-110.38 897.72,-100.99 857.57,-97.01"/>
# <polygon fill="black" stroke="black" stroke-width="0.1" points="858.01,-93.53 847.73,-96.12 857.38,-100.51 858.01,-93.53"/>
# <text text-anchor="middle" x="1046.88" y="-614.95" font-family="Times,serif" font-size="14.00">0.0</text>
# </g>
# <!-- Не выходит на связь -->
# <g id="node5" class="node">
# <title>Не выходит на связь</title>
# <polygon fill="#cecece" stroke="black" points="389,-793 251.5,-793 251.5,-752 389,-752 389,-793"/>
# <text text-anchor="middle" x="320.25" y="-775.7" font-family="Times,serif" font-size="14.00">Не выходит на связь</text>
# <text text-anchor="middle" x="320.25" y="-759.2" font-family="Times,serif" font-size="14.00">mean_time: 435.3</text>
# </g>
# <!-- Рассмотрение рекрутером&#45;&gt;Не выходит на связь -->
# <g id="edge26" class="edge">
# <title>Рассмотрение рекрутером&#45;&gt;Не выходит на связь</title>
# <path fill="none" stroke="black" stroke-width="0.1" d="M320.32,-1125.53C293.25,-1110.33 264.25,-1086.47 264.25,-1054 264.25,-1054 264.25,-1054 264.25,-865 264.25,-840.77 278.71,-817.54 292.93,-800.55"/>
# <polygon fill="black" stroke="black" stroke-width="0.1" points="295.32,-803.14 299.3,-793.32 290.06,-798.51 295.32,-803.14"/>
# <text text-anchor="middle" x="272.88" y="-954.45" font-family="Times,serif" font-size="14.00">0.0</text>
# </g>
# <!-- Резерв -->
# <g id="node7" class="node">
# <title>Резерв</title>
# <polygon fill="#e8e8e8" stroke="black" points="510.5,-886.5 388,-886.5 388,-845.5 510.5,-845.5 510.5,-886.5"/>
# <text text-anchor="middle" x="449.25" y="-869.2" font-family="Times,serif" font-size="14.00">Резерв</text>
# <text text-anchor="middle" x="449.25" y="-852.7" font-family="Times,serif" font-size="14.00">mean_time: 181.02</text>
# </g>
# <!-- Рассмотрение рекрутером&#45;&gt;Резерв -->
# <g id="edge36" class="edge">
# <title>Рассмотрение рекрутером&#45;&gt;Резерв</title>
# <path fill="none" stroke="black" stroke-width="0.1" d="M373.95,-1125.75C376.09,-1120.06 378.34,-1113.81 380.25,-1108 405.11,-1032.48 429.63,-942.02 441.63,-896.4"/>
# <polygon fill="black" stroke="black" stroke-width="0.1" points="444.95,-897.55 444.1,-886.99 438.18,-895.77 444.95,-897.55"/>
# <text text-anchor="middle" x="422.01" y="-1001.2" font-family="Times,serif" font-size="14.00">0.0</text>
# </g>
# <!-- Планирование интервью -->
# <g id="node9" class="node">
# <title>Планирование интервью</title>
# <polygon fill="#ebebeb" stroke="black" points="886.38,-699.5 724.12,-699.5 724.12,-658.5 886.38,-658.5 886.38,-699.5"/>
# <text text-anchor="middle" x="805.25" y="-682.2" font-family="Times,serif" font-size="14.00">Планирование интервью</text>
# <text text-anchor="middle" x="805.25" y="-665.7" font-family="Times,serif" font-size="14.00">mean_time: 150.39</text>
# </g>
# <!-- Рассмотрение рекрутером&#45;&gt;Планирование интервью -->
# <g id="edge29" class="edge">
# <title>Рассмотрение рекрутером&#45;&gt;Планирование интервью</title>
# <path fill="none" stroke="black" stroke-width="0.1" d="M450.77,-1141.94C623.38,-1133.52 1000.25,-1108.88 1000.25,-1054 1000.25,-1054 1000.25,-1054 1000.25,-911.75 1000.25,-816.22 983.36,-776.52 908.25,-717.5 901.85,-712.47 894.72,-708.08 887.27,-704.24"/>
# <polygon fill="black" stroke="black" stroke-width="0.1" points="889.07,-701.23 878.54,-700.06 886.05,-707.54 889.07,-701.23"/>
# <text text-anchor="middle" x="1008.88" y="-907.7" font-family="Times,serif" font-size="14.00">0.0</text>
# </g>
# <!-- Готов к переводу -->
# <g id="node14" class="node">
# <title>Готов к переводу</title>
# <polygon fill="#efefef" stroke="black" points="380.5,-207.5 258,-207.5 258,-166.5 380.5,-166.5 380.5,-207.5"/>
# <text text-anchor="middle" x="319.25" y="-190.2" font-family="Times,serif" font-size="14.00">Готов к переводу</text>
# <text text-anchor="middle" x="319.25" y="-173.7" font-family="Times,serif" font-size="14.00">mean_time: 109.35</text>
# </g>
# <!-- Рассмотрение рекрутером&#45;&gt;Готов к переводу -->
# <g id="edge21" class="edge">
# <title>Рассмотрение рекрутером&#45;&gt;Готов к переводу</title>
# <path fill="none" stroke="black" stroke-width="0.1" d="M281.81,-1142.38C221.23,-1135.08 150.25,-1113.77 150.25,-1054 150.25,-1054 150.25,-1054 150.25,-326.25 150.25,-270.87 205.28,-233.68 252.54,-211.95"/>
# <polygon fill="black" stroke="black" stroke-width="0.1" points="253.71,-215

# %%
original_duration = simulation_original.get_result()["time"].mean()
optimized_duration = simulation.get_result()["time"].mean()

print(f"Исходная средняя длительность процесса: {original_duration:.2f} часов")
print(f"Оптимизированная средняя длительность процесса: {optimized_duration:.2f} часов")
# Out:
# Исходная средняя длительность процесса: 346.94 часов
# Оптимизированная средняя длительность процесса: 188.41 часов
